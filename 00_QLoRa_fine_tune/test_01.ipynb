# %% [markdown]
# ### Dataset 저장폴더 변경하여 로드

# %%
from datasets import load_dataset

# %%
ko_data_01 = load_dataset("allenai/c4", "ko", cache_dir="/mnt/t7/.cache/huggingface/datasets")
# Out:
# ...
# Resolving data files:   0%|          | 0/1024 [00:00<?, ?it/s]
# ...
# ...
# ...
# Retrying in 1s [Retry 1/5].
# ...
# IOStream.flush timed out
# ...
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Loading dataset shards:   0%|          | 0/198 [00:00<?, ?it/s]

# %%
ko_data_02 = load_dataset("Gunulhona/llm_datasets", cache_dir="/mnt/t7/.cache/huggingface/datasets")
# Out:
# ...
# Generating train split: 0 examples [00:00, ? examples/s]
# Failed to read file '/mnt/t7/.cache/huggingface/datasets/downloads/2425de3ecc38ac65a7bf8c82e2d313c8a37060be24e116a451387b837d7b6b3e' with error <class 'datasets.table.CastError'>: Couldn't cast
# instruction: string
# input: string
# output: string
# -- schema metadata --
# huggingface: '{"info": {"features": {"instruction": {"dtype": "string", "' + 116
# to
# {'instruction': Value(dtype='string', id=None), 'input': Value(dtype='string', id=None), 'output': Value(dtype='string', id=None), 'type': Value(dtype='string', id=None), 'template': Value(dtype='string', id=None)}
# because column names don't match
# ---------------------------------------------------------------------------
# CastError                                 Traceback (most recent call last)
# ...

# %% [markdown]
# - https://huggingface.co/beomi/gemma-ko-7b
#
# - https://huggingface.co/google/gemma-7b
#
# - https://huggingface.co/CohereForAI/c4ai-command-r-v01-4bit

# %%
ko_data_01['train'][15000000]['text']
# Out:
# "[14호] 우리도 액터다! : 발전대안 피다\n피다's View[14호] 우리도 액터다!\n우리도 액터다!\n국제개발협력은 다양한 행위자들의 참여로 이루어지는 활동이다. 각국 정부, 다자간협력기구, NGO, 기업 등이 주요 국제개발협력 분야에서 행위자(Actors)로 여겨지는 주체들이다. 각 주체들은 각각 고유한 역할을 하고, 또 다른 행위자들과 협력 하면서 이 분야에 기여하고 있다. 하지만 국제개발협력의 행위자 목록을 보고 있으면 두 가지 질문을 하게 된다. 하나는 ‘왜 이들 이외의 참여자들은 행위자로 여겨지거나 인정받지 못하는 가’이고, 다른 하나는 ‘소수의 전문가들이 아닌 다수의 일반 참여자들의 역할은 간과되고 있는 것은 아닌가’ 하는 점이다. 위에 언급된 행위자들보다 가장 우선적으로 언급하고 고려해야 할 행위자는 개발도상국의 시민들이다. 개발협력 프로그램에 참여하는 개도국의 시민들은 가장 중요한 당사자이다. 모든 프로그램은 우선적으로 시민 개개인의 삶의 변화를 목적으로 하기 때문이다.\n하지만 주민(시민) 당사자들은 많은 활동에서 간과되거나 배제되기 일쑤이다. 가령 프로그램의 평가보고서를 발행하는 경우에 그 보고서를 그 나라 혹은 민족의 언어로 번역하고, 주민(시민)들과 함께 결과를 공유하는 경우는 거의 찾아보기 어렵다. 아무리 의미 있는 연구가 이뤄지고, 성과를 확인한다 하더라도 정작 당사자들이 이를 확인할 수 없다면 이는 순서가 많이 뒤바뀐 것이 아닐까? 또한 프로그램을 기획할 때 주민(시민)들의 의사는 얼마나 반영되고 있을까? 전문가들이 책상에서 임의로, 그리고 일방적으로 목적, 목표를 수립한다면 첫 단추부터 잘못 끼우고 있는 것은 아닐까? 당사자들이 바라는 사회상과 삶의 내용, 구체적인 욕구가 담겨지지 않은 프로그램은 과연 누구를 위한 프로그램인가? 유용한 시설을 기간 내에 안전하게 완공하는 결과 못지않게, 당사자들이 프로그램에 주체적이고 적극적으로 참여하는 과정에서 자신과 공동체의 잠재된 힘을 발견하고, 책임의식을 갖게 되는 체험의 과정이
# ...

# %%
ko_data_02 = load_dataset("squarelike/OpenOrca-gugugo-ko", cache_dir="/mnt/t7/.cache/huggingface/datasets")
# Out:
# ...
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
ko_data_02
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['question', 'system_prompt', 'response', 'id'],
#         num_rows: 2240294
#     })
# })

# %%
ko_data_02['train'][100]['system_prompt']
# Out:
# '당신은 인공지능 비서입니다. 사용자가 답변을 이해하기 위해 외부에서 검색할 필요가 없도록 자세한 답변을 제공하세요.'

# %%
print(ko_data_02['train'][100]['question'])
print(ko_data_02['train'][100]['response'])
# Out:
# 먼저 작업의 정의와 작업의 입력이 주어집니다.
# 입력은 혐오 발언 또는 모욕적인 트윗이 될 수 있습니다. 이러한 트윗이 주어지면, 트윗에서 혐오 발언 또는 모욕적인 표현을 출력하세요. 출력에는 이러한 표현만 포함되어야 합니다. 출력은 트윗 자체 내에서 제공되어야 합니다. 트윗에 없는 단어나 문구를 생성하지 마세요.
#
# 제이크 태퍼는 가짜 미디어가 컴페티 피자에서 총기 난사를 선동했다고 말하며 CNN이 끊임없이 거짓 내러티브를 제공하여 미국 전역에서 경찰관을 살해하고 여러 도시에서 인종 폭동을 촉발시켰다고 말합니다. 트럼프나 배넌이 다치면 CNN의 피가 흐르고 피자가 게이트에 있습니다.</사용자>
# 출력:
# 백인 인종주의에 대한 끊임없는 거짓 내러티브
