# %% [markdown]
# # 1. Load Environment & Huggingface, W&B login

# %%
import wandb
import os
os.environ["WANDB_PROJECT"]="QLoRA_Instruction_finetune"

wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: aeolian83. Use `wandb login --relogin` to force relogin
# True

# %%
from datasets import load_dataset
from huggingface_hub import login
from dotenv import load_dotenv

load_dotenv()


login(token= os.environ["HF_TOKEN"])
# Out:
# Token has not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /home/aeolian83/.cache/huggingface/token
# Login successful

# %% [markdown]
# # 2. Dataset Load
#
# - 이 시스템에서는 작업을 외장하드에서 하고 있기 때문에 캐쉬폴더를 별도로 지정(In this system, tasks are being performed on an external hard drive, so a separate cache folder is specified.)

# %%
ko_instruction_01 = load_dataset("squarelike/OpenOrca-gugugo-ko", cache_dir="/mnt/t7/.cache/huggingface/datasets")

# %%
ko_instruction_01 = ko_instruction_01.shuffle(seed=2160)

# %%
ko_instruction_01
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['question', 'system_prompt', 'response', 'id'],
#         num_rows: 2240294
#     })
# })

# %%
ko_instruction_01 = ko_instruction_01['train'].train_test_split(test_size=0.02)

# %%
ko_instruction_01
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['question', 'system_prompt', 'response', 'id'],
#         num_rows: 2195488
#     })
#     test: Dataset({
#         features: ['question', 'system_prompt', 'response', 'id'],
#         num_rows: 44806
#     })
# })

# %%
ko_instruction_01['train'][1500]['question']
# Out:
# '질문: "2000년대에 200만 달러 미만의 탐사 비용이 지출되었나요?"  컨텍스트: "미국 달러로 1파운드당 59달러에 이르는 우라늄 매장량의 5.5%는 경제적으로 실행 가능한 매장량으로 추정되며, 3500만 톤은 광물로 분류됩니다(향후 경제적 채굴이 가능한 합리적 전망). 가격은 2003년 5월 10달러/lb에서 2007년 7월 138달러/lb로 상승했습니다. 이로 인해 2005년에는 20억 달러가 지출되었고, 이는 전년 대비 54% 증가한 금액입니다. 이 추세는 2006년까지 이어져 2004년에 비해 250% 이상 증가한 7억 7,400만 달러 이상의 지출이 이루어졌습니다. OECD 원자력 에너지 기구는 2007년 탐사 비용이 2006년과 같을 것으로 예상했습니다."  Answer:\nA:'

# %%
ko_instruction_01['train'][1500]['system_prompt']
# Out:
# ''

# %%
ko_instruction_01['train'][1500]['response']
# Out:
# '2004년에는 200만 달러 미만의 탐사 비용이 지출되었습니다.'

# %% [markdown]
# # 3. Model Load
#
# - QLoRA로 finetune을 하기위해 일반 7B 모델을 BitsAndBytes를 통해 양자화(4bit quantization)하여 로드, 훈련속도 향상을 위해 데이터 타입을 fp32가 아니라 fp16으로 로드(차후에는 bf16으로 로드해서 훈련예정)
# - To finetune with QLoRA, a standard 7B model is quantized (4-bit quantization) through BitsAndBytes for loading, and to improve training speed, the data type is loaded as fp16 instead of fp32 (with plans to load and train with bf16 in the future).
#
#
# ```python
#
# quantization_config=BitsAndBytesConfig(
#         load_in_4bit=True,
#         llm_int8_threshold=6.0,
#         llm_int8_has_fp16_weight=False,
#         bnb_4bit_compute_dtype=torch.bfloat16,
#         bnb_4bit_use_double_quant=True,
#         bnb_4bit_quant_type="nf4",
#     ),
# ```
#
# ### *Reference
#
# - https://github.com/huggingface/peft/blob/main/examples/fp4_finetuning/finetune_fp4_opt_bnb_peft.py
# - https://colab.research.google.com/drive/19AFEOrCI6-bc7h9RTso_NndRwXJRaJ25?usp=sharing

# %%
import torch
import transformers
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig, TrainingArguments
from peft import LoraConfig, PeftModel, get_peft_model
from trl import SFTTrainer

# %%
output_dir = "./results"
model_id = "beomi/llama-2-ko-7b"
device_map = {"": 0}

# %%
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    quantization_config=BitsAndBytesConfig(
        load_in_4bit=True,
        llm_int8_threshold=6.0,
        llm_int8_has_fp16_weight=False,
        bnb_4bit_compute_dtype=torch.float16,
        bnb_4bit_use_double_quant=True,
        bnb_4bit_quant_type="nf4",
    ),
    device_map=device_map,
    torch_dtype=torch.float16,
    cache_dir="/mnt/t7/.cache/huggingface/models",
)
tokenizer = AutoTokenizer.from_pretrained(model_id, cache_dir="/mnt/t7/.cache/huggingface/models")
# Out:
# Loading checkpoint shards:   0%|          | 0/15 [00:00<?, ?it/s]

# %% [markdown]
# ## (1) Check Trainable Parameter
#
# - 아래 코드대로 모델을 로드하면 훈련하는 파라미터수를 확인할 수 있다.

# %%
# from peft import prepare_model_for_kbit_training

# model.gradient_checkpointing_enable()
# model = prepare_model_for_kbit_training(model)

# %%
def print_trainable_parameters(model):
    """
    Print the number of trainable parameters in the model.
    """
    trainable_params = 0
    all_param = 0
    for _, param in model.named_parameters():
        all_param += param.numel()
        if param.requires_grad:
            trainable_params += param.numel()
    print(
        f"trainable params: {trainable_params} || all params: {all_param} || trainble%: {100 * trainable_params / all_param}"
    )

# %% [markdown]
# ### PEFT훈련을 위한 CONFIG설정, 이 부분은 Trainable Parameter를 확인하지 않아도 QLoRA를 위해서는 무소건 해야 한다.("For PEFT training configuration, this step must be done unconditionally for QLoRA, even without checking for Trainable Parameters.")

# %%
# peft_config = LoraConfig(
#     r=64,
#     lora_alpha=16,
#     lora_dropout=0.1,
#     inference_mode=False,
#     task_type="CAUSAL_LM",
# )

peft_config = LoraConfig(
    r=64,
    lora_alpha=32,
    target_modules=["q_proj", "v_proj", "out_proj", "fc1", "fc2"],
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM",
)

# %%
# model = get_peft_model(model, peft_config)
# print_trainable_parameters(model)

# %%
model.config.use_cache = False # silence the warnings. Please re-enable for inference!
model.config.pretraining_tp = 1

# %%
tokenizer.pad_token = tokenizer.eos_token

# 학습 진행 중 loss가 치솟다가 0.0으로 떨어지는 문제 해결을 위해 사용
tokenizer.padding_side = "right"

# %%
def format_instruction(sample):
    system_prompt = f"### System: {sample['system_prompt']}"
    input = f"### Human: {sample['question']}" if len(sample["question"]) > 0 else None
    output = f"### Assistant\n{sample['response']}"
    # join all the parts together
    prompt = "\n\n".join([i for i in [system_prompt, input, output] if i is not None])
    return prompt

# template dataset to add prompt to each sample
def template_dataset(sample):
    sample["text"] = f"{format_instruction(sample)}{tokenizer.eos_token}"
    return sample

# %%
train_dataset = ko_instruction_01['train'].map(template_dataset, remove_columns=list(ko_instruction_01['train'].features), num_proc=10)
# Out:
# Map (num_proc=10):   0%|          | 0/2195488 [00:00<?, ? examples/s]

# %%
test_dataset = ko_instruction_01['test'].map(template_dataset, remove_columns=list(ko_instruction_01['test'].features), num_proc=10)
# Out:
# Map (num_proc=10):   0%|          | 0/44806 [00:00<?, ? examples/s]

# %%
training_arguments = TrainingArguments(
    output_dir=output_dir,
    save_steps=200,
    save_total_limit=3, # 가장 최근 체크포인트 3개만 저장합니다.
    logging_steps=30,
    report_to="wandb",
    learning_rate=3e-4,
    max_grad_norm=0.3,
    num_train_epochs=1, # epochs 대신 max_steps을 기준으로 할 수 있습니다.
    warmup_ratio=0.03,
    per_device_train_batch_size=1,
    gradient_accumulation_steps=2,
    optim="paged_adamw_32bit", # paged_adamw_8bit 사용시 메모리를 더 절약할 수 있지만 loss가 0으로 떨어지는 문제가 있습니다.
    group_by_length=True,
    fp16 = False, # 코랩 무료버전에서 실행 시 "True"를 사용하세요
    bf16 = True, # 코랩 무료버전에서 실행 시 "False"를 사용하세요
    lr_scheduler_type="constant",
)

trainer = SFTTrainer(
    model=model,
    train_dataset=train_dataset,
    peft_config=peft_config,
    dataset_text_field="text",
    max_seq_length=1024,
    tokenizer=tokenizer,
    args=training_arguments,
    packing=False,
)
# Out:
# Map:   0%|          | 0/2195488 [00:00<?, ? examples/s]
# /home/aeolian83/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/accelerate/accelerator.py:432: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(

# %%
trainer.train(resume_from_checkpoint=True)
# Out:
#   0%|          | 0/1097744 [00:00<?, ?it/s]
# {'loss': 1.2978, 'grad_norm': 0.89453125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1235, 'grad_norm': 1.703125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2271, 'grad_norm': 0.71484375, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.0699, 'grad_norm': 0.72265625, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.3677, 'grad_norm': 0.96484375, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1357, 'grad_norm': 0.83203125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1649, 'grad_norm': 2.046875, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2373, 'grad_norm': 1.0078125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2063, 'grad_norm': 2.21875, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2309, 'grad_norm': 1.15625, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.0992, 'grad_norm': 0.921875, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1568, 'grad_norm': 1.4140625, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2178, 'grad_norm': 0.7265625, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.0694, 'grad_norm': 0.89453125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2938, 'grad_norm': 1.1953125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2259, 'grad_norm': 0.9765625, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2374, 'grad_norm': 1.421875, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2636, 'grad_norm': 1.21875, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2058, 'grad_norm': 1.9296875, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.155, 'grad_norm': 1.1796875, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2239, 'grad_norm': 0.71484375, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1613, 'grad_norm': 0.9921875, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2526, 'grad_norm': 0.99609375, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2374, 'grad_norm': 1.0390625, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.3492, 'grad_norm': 0.9765625, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.191, 'grad_norm': 0.9609375, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.3251, 'grad_norm': 1.140625, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1561, 'grad_norm': 1.140625, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1168, 'grad_norm': 0.291015625, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.3139, 'grad_norm': 1.2265625, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.228, 'grad_norm': 0.7890625, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1661, 'grad_norm': 1.1875, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1358, 'grad_norm': 1.1796875, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.0704, 'grad_norm': 1.7109375, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.3691, 'grad_norm': 1.3828125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1898, 'grad_norm': 0.7734375, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1709, 'grad_norm': 1.171875, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1744, 'grad_norm': 0.70703125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1624, 'grad_norm': 1.5078125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.3049, 'grad_norm': 0.80078125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1572, 'grad_norm': 0.8359375, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.0766, 'grad_norm': 0.73828125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.3643, 'grad_norm': 0.8359375, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1874, 'grad_norm': 1.2578125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.3087, 'grad_norm': 1.0078125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2024, 'grad_norm': 0.7734375, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1665, 'grad_norm': 1.296875, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.174, 'grad_norm': 0.8515625, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1821, 'grad_norm': 1.09375, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2703, 'grad_norm': 1.2578125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1445, 'grad_norm': 0.83984375, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1794, 'grad_norm': 1.015625, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.274, 'grad_norm': 0.8359375, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.0498, 'grad_norm': 0.2275390625, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2663, 'grad_norm': 0.85546875, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.0942, 'grad_norm': 0.83203125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2745, 'grad_norm': 1.265625, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1971, 'grad_norm': 0.9453125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1029, 'grad_norm': 0.95703125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.3522, 'grad_norm': 0.796875, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2507, 'grad_norm': 0.921875, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.3033, 'grad_norm': 1.328125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2234, 'grad_norm': 0.83203125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.0614, 'grad_norm': 0.5234375, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.3063, 'grad_norm': 1.2109375, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2075, 'grad_norm': 1.0078125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1307, 'grad_norm': 1.109375, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.3217, 'grad_norm': 1.078125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1405, 'grad_norm': 0.82421875, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1835, 'grad_norm': 1.21875, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1458, 'grad_norm': 0.7578125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1513, 'grad_norm': 0.8671875, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2267, 'grad_norm': 0.77734375, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2188, 'grad_norm': 1.5546875, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2055, 'grad_norm': 0.953125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2187, 'grad_norm': 0.86328125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1793, 'grad_norm': 1.3359375, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2933, 'grad_norm': 1.1171875, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.0329, 'grad_norm': 1.1875, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.3046, 'grad_norm': 0.9453125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2658, 'grad_norm': 0.76953125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2709, 'grad_norm': 0.6875, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1394, 'grad_norm': 0.9140625, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1029, 'grad_norm': 0.828125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2137, 'grad_norm': 1.1171875, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1749, 'grad_norm': 0.76953125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.138, 'grad_norm': 1.0625, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2237, 'grad_norm': 0.8046875, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.0429, 'grad_norm': 0.609375, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2363, 'grad_norm': 0.7890625, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.0817, 'grad_norm': 0.66015625, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2244, 'grad_norm': 1.140625, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.3313, 'grad_norm': 0.93359375, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.0546, 'grad_norm': 0.796875, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2745, 'grad_norm': 1.0390625, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1519, 'grad_norm': 0.8359375, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2057, 'grad_norm': 0.8046875, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1971, 'grad_norm': 1.0, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1777, 'grad_norm': 0.90625, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2877, 'grad_norm': 1.203125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1843, 'grad_norm': 0.890625, 'learning_rate': 0.0003, 'epoch': 0.23}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 trainer.train(resume_from_checkpoint=True)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/trl/trainer/sft_trainer.py:360, in SFTTrainer.train(self, *args, **kwargs)
#     357 if self.neftune_noise_alpha is not None and not self._trainer_supports_neftune:
#     358     self.model = self._trl_activate_neftune(self.model)
# --> 360 output = super().train(*args, **kwargs)
#     362 # After training we make sure to retrieve back the original forward pass method
#     363 # for the embedding layer by removing the forward post hook.
#     364 if self.neftune_noise_alpha is not None and not self._trainer_supports_neftune:
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/transformers/trainer.py:1624, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1622         hf_hub_utils.enable_progress_bars()
#    1623 else:
# -> 1624     return inner_training_loop(
#    1625         args=args,
#    1626         resume_from_checkpoint=resume_from_checkpoint,
#    1627         trial=trial,
#    1628         ignore_keys_for_eval=ignore_keys_for_eval,
#    1629     )
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/transformers/trainer.py:1961, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1958     self.control = self.callback_handler.on_step_begin(args, self.state, self.control)
#    1960 with self.accelerator.accumulate(model):
# -> 1961     tr_loss_step = self.training_step(model, inputs)
#    1963 if (
#    1964     args.logging_nan_inf_filter
#    1965     and not is_torch_tpu_available()
#    1966     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    1967 ):
#    1968     # if loss is nan or inf simply add the average of previous logged losses
#    1969     tr_loss += tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/transformers/trainer.py:2902, in Trainer.training_step(self, model, inputs)
#    2899     return loss_mb.reduce_mean().detach().to(self.args.device)
#    2901 with self.compute_loss_context_manager():
# -> 2902     loss = self.compute_loss(model, inputs)
#    2904 if self.args.n_gpu > 1:
#    2905     loss = loss.mean()  # mean() to average on multi-gpu parallel training
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/transformers/trainer.py:2925, in Trainer.compute_loss(self, model, inputs, return_outputs)
#    2923 else:
#    2924     labels = None
# -> 2925 outputs = model(**inputs)
#    2926 # Save past state if it exists
#    2927 # TODO: this needs to be fixed and made cleaner later.
#    2928 if self.args.past_index >= 0:
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/accelerate/utils/operations.py:822, in convert_outputs_to_fp32.<locals>.forward(*args, **kwargs)
#     821 def forward(*args, **kwargs):
# --> 822     return model_forward(*args, **kwargs)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/accelerate/utils/operations.py:810, in ConvertOutputsToFp32.__call__(self, *args, **kwargs)
#     809 def __call__(self, *args, **kwargs):
# --> 810     return convert_to_fp32(self.model_forward(*args, **kwargs))
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/torch/amp/autocast_mode.py:16, in autocast_decorator.<locals>.decorate_autocast(*args, **kwargs)
#      13 @functools.wraps(func)
#      14 def decorate_autocast(*args, **kwargs):
#      15     with autocast_instance:
# ---> 16         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/peft/peft_model.py:1091, in PeftModelForCausalLM.forward(self, input_ids, attention_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict, task_ids, **kwargs)
#    1089     if peft_config.peft_type == PeftType.POLY:
#    1090         kwargs["task_ids"] = task_ids
# -> 1091     return self.base_model(
#    1092         input_ids=input_ids,
#    1093         attention_mask=attention_mask,
#    1094         inputs_embeds=inputs_embeds,
#    1095         labels=labels,
#    1096         output_attentions=output_attentions,
#    1097         output_hidden_states=output_hidden_states,
#    1098         return_dict=return_dict,
#    1099         **kwargs,
#    1100     )
#    1102 batch_size = _get_batch_size(input_ids, inputs_embeds)
#    1103 if attention_mask is not None:
#    1104     # concat prompt attention mask
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/peft/tuners/tuners_utils.py:160, in BaseTuner.forward(self, *args, **kwargs)
#     159 def forward(self, *args: Any, **kwargs: Any):
# --> 160     return self.model.forward(*args, **kwargs)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/accelerate/hooks.py:166, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     164         output = module._old_forward(*args, **kwargs)
#     165 else:
# --> 166     output = module._old_forward(*args, **kwargs)
#     167 return module._hf_hook.post_forward(module, output)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/transformers/models/llama/modeling_llama.py:1176, in LlamaForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1173 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1175 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1176 outputs = self.model(
#    1177     input_ids=input_ids,
#    1178     attention_mask=attention_mask,
#    1179     position_ids=position_ids,
#    1180     past_key_values=past_key_values,
#    1181     inputs_embeds=inputs_embeds,
#    1182     use_cache=use_cache,
#    1183     output_attentions=output_attentions,
#    1184     output_hidden_states=output_hidden_states,
#    1185     return_dict=return_dict,
#    1186     cache_position=cache_position,
#    1187 )
#    1189 hidden_states = outputs[0]
#    1190 if self.config.pretraining_tp > 1:
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/accelerate/hooks.py:166, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     164         output = module._old_forward(*args, **kwargs)
#     165 else:
# --> 166     output = module._old_forward(*args, **kwargs)
#     167 return module._hf_hook.post_forward(module, output)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/transformers/models/llama/modeling_llama.py:1019, in LlamaModel.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1008     layer_outputs = self._gradient_checkpointing_func(
#    1009         decoder_layer.__call__,
#    1010         hidden_states,
#    (...)
#    1016         cache_position,
#    1017     )
#    1018 else:
# -> 1019     layer_outputs = decoder_layer(
#    1020         hidden_states,
#    1021         attention_mask=causal_mask,
#    1022         position_ids=position_ids,
#    1023         past_key_value=past_key_values,
#    1024         output_attentions=output_attentions,
#    1025         use_cache=use_cache,
#    1026         cache_position=cache_position,
#    1027     )
#    1029 hidden_states = layer_outputs[0]
#    1031 if use_cache:
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/accelerate/hooks.py:166, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     164         output = module._old_forward(*args, **kwargs)
#     165 else:
# --> 166     output = module._old_forward(*args, **kwargs)
#     167 return module._hf_hook.post_forward(module, output)
#
# KeyboardInterrupt:

# %%
# trainer.model.save_pretrained(output_dir)

# %% [markdown]
# ### 훈련이 정체 되어 러닝레이트 수정

# %%
training_arguments.learning_rate = 2e-6

# %%
trainer = SFTTrainer(
    model=model,
    train_dataset=train_dataset,
    peft_config=peft_config,
    dataset_text_field="text",
    max_seq_length=1024,
    tokenizer=tokenizer,
    args=training_arguments,
    packing=False,
)

trainer.train(resume_from_checkpoint=True)
# Out:
# /home/aeolian83/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/accelerate/accelerator.py:432: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(
#   0%|          | 0/1097744 [00:00<?, ?it/s]
# {'loss': 1.4401, 'grad_norm': 0.890625, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1819, 'grad_norm': 1.109375, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2101, 'grad_norm': 0.9453125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2069, 'grad_norm': 1.796875, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2275, 'grad_norm': 0.81640625, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.2486, 'grad_norm': 0.90625, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.1266, 'grad_norm': 1.015625, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.285, 'grad_norm': 0.80078125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.114, 'grad_norm': 0.95703125, 'learning_rate': 0.0003, 'epoch': 0.23}
# {'loss': 1.3299, 'grad_norm': 1.078125, 'learning_rate': 0.0003, 'epoch': 0.23}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 12
#       1 trainer = SFTTrainer(
#       2     model=model,
#       3     train_dataset=train_dataset,
#    (...)
#       9     packing=False,
#      10 )
# ---> 12 trainer.train(resume_from_checkpoint=True)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/trl/trainer/sft_trainer.py:360, in SFTTrainer.train(self, *args, **kwargs)
#     357 if self.neftune_noise_alpha is not None and not self._trainer_supports_neftune:
#     358     self.model = self._trl_activate_neftune(self.model)
# --> 360 output = super().train(*args, **kwargs)
#     362 # After training we make sure to retrieve back the original forward pass method
#     363 # for the embedding layer by removing the forward post hook.
#     364 if self.neftune_noise_alpha is not None and not self._trainer_supports_neftune:
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/transformers/trainer.py:1624, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1622         hf_hub_utils.enable_progress_bars()
#    1623 else:
# -> 1624     return inner_training_loop(
#    1625         args=args,
#    1626         resume_from_checkpoint=resume_from_checkpoint,
#    1627         trial=trial,
#    1628         ignore_keys_for_eval=ignore_keys_for_eval,
#    1629     )
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/transformers/trainer.py:1961, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1958     self.control = self.callback_handler.on_step_begin(args, self.state, self.control)
#    1960 with self.accelerator.accumulate(model):
# -> 1961     tr_loss_step = self.training_step(model, inputs)
#    1963 if (
#    1964     args.logging_nan_inf_filter
#    1965     and not is_torch_tpu_available()
#    1966     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    1967 ):
#    1968     # if loss is nan or inf simply add the average of previous logged losses
#    1969     tr_loss += tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/transformers/trainer.py:2911, in Trainer.training_step(self, model, inputs)
#    2909         scaled_loss.backward()
#    2910 else:
# -> 2911     self.accelerator.backward(loss)
#    2913 return loss.detach() / self.args.gradient_accumulation_steps
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/accelerate/accelerator.py:2001, in Accelerator.backward(self, loss, **kwargs)
#    1999     self.scaler.scale(loss).backward(**kwargs)
#    2000 else:
# -> 2001     loss.backward(**kwargs)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/torch/_tensor.py:522, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     512 if has_torch_function_unary(self):
#     513     return handle_torch_function(
#     514         Tensor.backward,
#     515         (self,),
#    (...)
#     520         inputs=inputs,
#     521     )
# --> 522 torch.autograd.backward(
#     523     self, gradient, retain_graph, create_graph, inputs=inputs
#     524 )
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/torch/autograd/__init__.py:266, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     261     retain_graph = create_graph
#     263 # The reason we repeat the same comment below is that
#     264 # some Python versions print out the first line of a multi-line function
#     265 # calls in the traceback and some print out the last line
# --> 266 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267     tensors,
#     268     grad_tensors_,
#     269     retain_graph,
#     270     create_graph,
#     271     inputs,
#     272     allow_unreachable=True,
#     273     accumulate_grad=True,
#     274 )
#
# KeyboardInterrupt:

# %%
# trainer.model.save_pretrained(output_dir)

# %% [markdown]
# ### 허깅페이스에서 훈련 도중 러닝레이트가 수정 안되는 경우가 많다 한다.
# - 스케쥴러 변경을 시도해 보기로 한다.

# %%
training_arguments.lr_scheduler_type="linear"

# %%
trainer = SFTTrainer(
    model=model,
    train_dataset=train_dataset,
    peft_config=peft_config,
    dataset_text_field="text",
    max_seq_length=1024,
    tokenizer=tokenizer,
    args=training_arguments,
    packing=False,
)

trainer.train(resume_from_checkpoint=True)
# Out:
# /home/aeolian83/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/accelerate/accelerator.py:432: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(
#   0%|          | 0/1097744 [00:00<?, ?it/s]
# {'loss': 1.4306, 'grad_norm': 0.796875, 'learning_rate': 0.00023748552560031778, 'epoch': 0.23}
# {'loss': 1.1129, 'grad_norm': 0.96484375, 'learning_rate': 0.0002374770733961238, 'epoch': 0.23}
# {'loss': 1.3266, 'grad_norm': 1.046875, 'learning_rate': 0.00023746862119192983, 'epoch': 0.23}
# {'loss': 1.0834, 'grad_norm': 0.71484375, 'learning_rate': 0.00023746016898773585, 'epoch': 0.23}
# {'loss': 1.1259, 'grad_norm': 1.25, 'learning_rate': 0.00023745171678354182, 'epoch': 0.23}
# {'loss': 1.1209, 'grad_norm': 1.1015625, 'learning_rate': 0.00023744326457934785, 'epoch': 0.23}
# {'loss': 1.0383, 'grad_norm': 0.9375, 'learning_rate': 0.00023743481237515387, 'epoch': 0.23}
# {'loss': 1.2496, 'grad_norm': 1.015625, 'learning_rate': 0.0002374263601709599, 'epoch': 0.23}
# {'loss': 1.2066, 'grad_norm': 0.87890625, 'learning_rate': 0.0002374179079667659, 'epoch': 0.23}
# {'loss': 1.1973, 'grad_norm': 0.984375, 'learning_rate': 0.00023740945576257192, 'epoch': 0.23}
# {'loss': 1.1831, 'grad_norm': 1.0, 'learning_rate': 0.00023740100355837794, 'epoch': 0.23}
# {'loss': 1.0658, 'grad_norm': 0.88671875, 'learning_rate': 0.00023739255135418397, 'epoch': 0.23}
# {'loss': 1.2603, 'grad_norm': 1.0703125, 'learning_rate': 0.00023738409914999, 'epoch': 0.23}
# {'loss': 1.2585, 'grad_norm': 1.390625, 'learning_rate': 0.000237375646945796, 'epoch': 0.23}
# {'loss': 1.1571, 'grad_norm': 1.421875, 'learning_rate': 0.00023736719474160201, 'epoch': 0.23}
# {'loss': 1.1133, 'grad_norm': 0.8828125, 'learning_rate': 0.00023735874253740804, 'epoch': 0.23}
# {'loss': 1.1418, 'grad_norm': 1.0859375, 'learning_rate': 0.00023735029033321406, 'epoch': 0.23}
# {'loss': 1.192, 'grad_norm': 1.21875, 'learning_rate': 0.00023734183812902003, 'epoch': 0.23}
# {'loss': 1.226, 'grad_norm': 0.7421875, 'learning_rate': 0.00023733338592482606, 'epoch': 0.23}
# {'loss': 1.2016, 'grad_norm': 1.0546875, 'learning_rate': 0.00023732493372063208, 'epoch': 0.23}
# {'loss': 1.1776, 'grad_norm': 0.87890625, 'learning_rate': 0.0002373164815164381, 'epoch': 0.23}
# {'loss': 0.9579, 'grad_norm': 0.62109375, 'learning_rate': 0.0002373080293122441, 'epoch': 0.23}
# {'loss': 1.2105, 'grad_norm': 0.96484375, 'learning_rate': 0.00023729957710805013, 'epoch': 0.23}
# {'loss': 1.2182, 'grad_norm': 0.859375, 'learning_rate': 0.00023729112490385615, 'epoch': 0.23}
# {'loss': 1.2157, 'grad_norm': 1.0703125, 'learning_rate': 0.00023728267269966218, 'epoch': 0.23}
# {'loss': 1.2074, 'grad_norm': 0.94140625, 'learning_rate': 0.0002372742204954682, 'epoch': 0.23}
# {'loss': 1.1256, 'grad_norm': 2.0, 'learning_rate': 0.0002372657682912742, 'epoch': 0.23}
# {'loss': 1.3668, 'grad_norm': 1.234375, 'learning_rate': 0.00023725731608708022, 'epoch': 0.23}
# {'loss': 1.2596, 'grad_norm': 0.79296875, 'learning_rate': 0.00023724886388288625, 'epoch': 0.23}
# {'loss': 1.1802, 'grad_norm': 1.09375, 'learning_rate': 0.00023724041167869227, 'epoch': 0.23}
# {'loss': 1.2068, 'grad_norm': 0.69140625, 'learning_rate': 0.00023723195947449824, 'epoch': 0.23}
# {'loss': 1.1309, 'grad_norm': 1.6875, 'learning_rate': 0.00023722350727030427, 'epoch': 0.23}
# {'loss': 1.1531, 'grad_norm': 0.9765625, 'learning_rate': 0.0002372150550661103, 'epoch': 0.23}
# {'loss': 1.183, 'grad_norm': 0.8984375, 'learning_rate': 0.00023720660286191632, 'epoch': 0.23}
# {'loss': 1.2125, 'grad_norm': 0.9765625, 'learning_rate': 0.00023719815065772232, 'epoch': 0.23}
# {'loss': 1.1902, 'grad_norm': 0.7421875, 'learning_rate': 0.00023718969845352834, 'epoch': 0.23}
# {'loss': 1.1487, 'grad_norm': 0.69921875, 'learning_rate': 0.00023718124624933436, 'epoch': 0.23}
# {'loss': 1.1981, 'grad_norm': 0.9375, 'learning_rate': 0.0002371727940451404, 'epoch': 0.23}
# {'loss': 1.248, 'grad_norm': 0.76953125, 'learning_rate': 0.0002371643418409464, 'epoch': 0.23}
# {'loss': 1.2064, 'grad_norm': 1.1953125, 'learning_rate': 0.0002371558896367524, 'epoch': 0.23}
# {'loss': 1.2531, 'grad_norm': 1.078125, 'learning_rate': 0.00023714743743255844, 'epoch': 0.23}
# {'loss': 1.0698, 'grad_norm': 1.453125, 'learning_rate': 0.00023713898522836446, 'epoch': 0.23}
# {'loss': 1.208, 'grad_norm': 0.94921875, 'learning_rate': 0.00023713053302417048, 'epoch': 0.23}
# {'loss': 1.2186, 'grad_norm': 0.8203125, 'learning_rate': 0.00023712208081997645, 'epoch': 0.23}
# {'loss': 1.1133, 'grad_norm': 1.65625, 'learning_rate': 0.00023711362861578248, 'epoch': 0.23}
# {'loss': 1.1685, 'grad_norm': 0.69140625, 'learning_rate': 0.0002371051764115885, 'epoch': 0.23}
# {'loss': 1.1668, 'grad_norm': 1.7890625, 'learning_rate': 0.00023709672420739453, 'epoch': 0.23}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 12
#       1 trainer = SFTTrainer(
#       2     model=model,
#       3     train_dataset=train_dataset,
#    (...)
#       9     packing=False,
#      10 )
# ---> 12 trainer.train(resume_from_checkpoint=True)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/trl/trainer/sft_trainer.py:360, in SFTTrainer.train(self, *args, **kwargs)
#     357 if self.neftune_noise_alpha is not None and not self._trainer_supports_neftune:
#     358     self.model = self._trl_activate_neftune(self.model)
# --> 360 output = super().train(*args, **kwargs)
#     362 # After training we make sure to retrieve back the original forward pass method
#     363 # for the embedding layer by removing the forward post hook.
#     364 if self.neftune_noise_alpha is not None and not self._trainer_supports_neftune:
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/transformers/trainer.py:1624, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1622         hf_hub_utils.enable_progress_bars()
#    1623 else:
# -> 1624     return inner_training_loop(
#    1625         args=args,
#    1626         resume_from_checkpoint=resume_from_checkpoint,
#    1627         trial=trial,
#    1628         ignore_keys_for_eval=ignore_keys_for_eval,
#    1629     )
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/transformers/trainer.py:1961, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1958     self.control = self.callback_handler.on_step_begin(args, self.state, self.control)
#    1960 with self.accelerator.accumulate(model):
# -> 1961     tr_loss_step = self.training_step(model, inputs)
#    1963 if (
#    1964     args.logging_nan_inf_filter
#    1965     and not is_torch_tpu_available()
#    1966     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    1967 ):
#    1968     # if loss is nan or inf simply add the average of previous logged losses
#    1969     tr_loss += tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/transformers/trainer.py:2902, in Trainer.training_step(self, model, inputs)
#    2899     return loss_mb.reduce_mean().detach().to(self.args.device)
#    2901 with self.compute_loss_context_manager():
# -> 2902     loss = self.compute_loss(model, inputs)
#    2904 if self.args.n_gpu > 1:
#    2905     loss = loss.mean()  # mean() to average on multi-gpu parallel training
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/transformers/trainer.py:2925, in Trainer.compute_loss(self, model, inputs, return_outputs)
#    2923 else:
#    2924     labels = None
# -> 2925 outputs = model(**inputs)
#    2926 # Save past state if it exists
#    2927 # TODO: this needs to be fixed and made cleaner later.
#    2928 if self.args.past_index >= 0:
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/accelerate/utils/operations.py:822, in convert_outputs_to_fp32.<locals>.forward(*args, **kwargs)
#     821 def forward(*args, **kwargs):
# --> 822     return model_forward(*args, **kwargs)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/accelerate/utils/operations.py:810, in ConvertOutputsToFp32.__call__(self, *args, **kwargs)
#     809 def __call__(self, *args, **kwargs):
# --> 810     return convert_to_fp32(self.model_forward(*args, **kwargs))
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/torch/amp/autocast_mode.py:16, in autocast_decorator.<locals>.decorate_autocast(*args, **kwargs)
#      13 @functools.wraps(func)
#      14 def decorate_autocast(*args, **kwargs):
#      15     with autocast_instance:
# ---> 16         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/peft/peft_model.py:1091, in PeftModelForCausalLM.forward(self, input_ids, attention_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict, task_ids, **kwargs)
#    1089     if peft_config.peft_type == PeftType.POLY:
#    1090         kwargs["task_ids"] = task_ids
# -> 1091     return self.base_model(
#    1092         input_ids=input_ids,
#    1093         attention_mask=attention_mask,
#    1094         inputs_embeds=inputs_embeds,
#    1095         labels=labels,
#    1096         output_attentions=output_attentions,
#    1097         output_hidden_states=output_hidden_states,
#    1098         return_dict=return_dict,
#    1099         **kwargs,
#    1100     )
#    1102 batch_size = _get_batch_size(input_ids, inputs_embeds)
#    1103 if attention_mask is not None:
#    1104     # concat prompt attention mask
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/peft/tuners/tuners_utils.py:160, in BaseTuner.forward(self, *args, **kwargs)
#     159 def forward(self, *args: Any, **kwargs: Any):
# --> 160     return self.model.forward(*args, **kwargs)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/accelerate/hooks.py:166, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     164         output = module._old_forward(*args, **kwargs)
#     165 else:
# --> 166     output = module._old_forward(*args, **kwargs)
#     167 return module._hf_hook.post_forward(module, output)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/transformers/models/llama/modeling_llama.py:1176, in LlamaForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1173 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1175 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1176 outputs = self.model(
#    1177     input_ids=input_ids,
#    1178     attention_mask=attention_mask,
#    1179     position_ids=position_ids,
#    1180     past_key_values=past_key_values,
#    1181     inputs_embeds=inputs_embeds,
#    1182     use_cache=use_cache,
#    1183     output_attentions=output_attentions,
#    1184     output_hidden_states=output_hidden_states,
#    1185     return_dict=return_dict,
#    1186     cache_position=cache_position,
#    1187 )
#    1189 hidden_states = outputs[0]
#    1190 if self.config.pretraining_tp > 1:
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/accelerate/hooks.py:166, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     164         output = module._old_forward(*args, **kwargs)
#     165 else:
# --> 166     output = module._old_forward(*args, **kwargs)
#     167 return module._hf_hook.post_forward(module, output)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/transformers/models/llama/modeling_llama.py:1019, in LlamaModel.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1008     layer_outputs = self._gradient_checkpointing_func(
#    1009         decoder_layer.__call__,
#    1010         hidden_states,
#    (...)
#    1016         cache_position,
#    1017     )
#    1018 else:
# -> 1019     layer_outputs = decoder_layer(
#    1020         hidden_states,
#    1021         attention_mask=causal_mask,
#    1022         position_ids=position_ids,
#    1023         past_key_value=past_key_values,
#    1024         output_attentions=output_attentions,
#    1025         use_cache=use_cache,
#    1026         cache_position=cache_position,
#    1027     )
#    1029 hidden_states = layer_outputs[0]
#    1031 if use_cache:
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/accelerate/hooks.py:166, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     164         output = module._old_forward(*args, **kwargs)
#     165 else:
# --> 166     output = module._old_forward(*args, **kwargs)
#     167 return module._hf_hook.post_forward(module, output)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/transformers/models/llama/modeling_llama.py:740, in LlamaDecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position, **kwargs)
#     737 hidden_states = self.input_layernorm(hidden_states)
#     739 # Self Attention
# --> 740 hidden_states, self_attn_weights, present_key_value = self.self_attn(
#     741     hidden_states=hidden_states,
#     742     attention_mask=attention_mask,
#     743     position_ids=position_ids,
#     744     past_key_value=past_key_value,
#     745     output_attentions=output_attentions,
#     746     use_cache=use_cache,
#     747     cache_position=cache_position,
#     748     **kwargs,
#     749 )
#     750 hidden_states = residual + hidden_states
#     752 # Fully Connected
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/accelerate/hooks.py:166, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     164         output = module._old_forward(*args, **kwargs)
#     165 else:
# --> 166     output = module._old_forward(*args, **kwargs)
#     167 return module._hf_hook.post_forward(module, output)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/transformers/models/llama/modeling_llama.py:639, in LlamaSdpaAttention.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position)
#     627     return super().forward(
#     628         hidden_states=hidden_states,
#     629         attention_mask=attention_mask,
#    (...)
#     634         cache_position=cache_position,
#     635     )
#     637 bsz, q_len, _ = hidden_states.size()
# --> 639 query_states = self.q_proj(hidden_states)
#     640 key_states = self.k_proj(hidden_states)
#     641 value_states = self.v_proj(hidden_states)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/peft/tuners/lora/bnb.py:359, in Linear4bit.forward(self, x, *args, **kwargs)
#     357             output = output.to(expected_dtype)
#     358         output = output * scaling
# --> 359         result = result + output
#     361 return result
#
# KeyboardInterrupt:

# %%
training_arguments.learning_rate = 3e-5
training_arguments.lr_scheduler_type="linear"

# %%
trainer = SFTTrainer(
    model=model,
    train_dataset=train_dataset,
    peft_config=peft_config,
    dataset_text_field="text",
    max_seq_length=1024,
    tokenizer=tokenizer,
    args=training_arguments,
    packing=False,
)

trainer.train(resume_from_checkpoint=True)
# Out:
# /home/aeolian83/anaconda3/envs/llm_for_p311/lib/python3.11/site-packages/accelerate/accelerator.py:432: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(
#   0%|          | 0/1097744 [00:00<?, ?it/s]
# {'loss': 1.1436, 'grad_norm': 1.1796875, 'learning_rate': 0.00023708827200320055, 'epoch': 0.23}
# {'loss': 1.1665, 'grad_norm': 1.0234375, 'learning_rate': 0.00023707981979900655, 'epoch': 0.23}
# {'loss': 1.1498, 'grad_norm': 1.1953125, 'learning_rate': 0.00023707136759481257, 'epoch': 0.23}
# {'loss': 1.2756, 'grad_norm': 1.2109375, 'learning_rate': 0.0002370629153906186, 'epoch': 0.23}
# {'loss': 1.1218, 'grad_norm': 0.92578125, 'learning_rate': 0.00023705446318642462, 'epoch': 0.23}
# {'loss': 1.3295, 'grad_norm': 1.0546875, 'learning_rate': 0.00023704601098223062, 'epoch': 0.23}
# {'loss': 1.1145, 'grad_norm': 0.6171875, 'learning_rate': 0.00023703755877803665, 'epoch': 0.23}
# {'loss': 1.1597, 'grad_norm': 1.328125, 'learning_rate': 0.00023702910657384267, 'epoch': 0.23}
# {'loss': 1.0881, 'grad_norm': 0.8984375, 'learning_rate': 0.0002370206543696487, 'epoch': 0.23}
# {'loss': 1.0414, 'grad_norm': 0.890625, 'learning_rate': 0.0002370122021654547, 'epoch': 0.23}
# {'loss': 1.2198, 'grad_norm': 0.78515625, 'learning_rate': 0.0002370037499612607, 'epoch': 0.23}
# {'loss': 1.1652, 'grad_norm': 0.6796875, 'learning_rate': 0.00023699529775706671, 'epoch': 0.23}
# {'loss': 1.1594, 'grad_norm': 0.66796875, 'learning_rate': 0.00023698684555287274, 'epoch': 0.23}
# {'loss': 1.222, 'grad_norm': 0.8671875, 'learning_rate': 0.00023697839334867876, 'epoch': 0.23}
# {'loss': 1.0585, 'grad_norm': 0.6953125, 'learning_rate': 0.00023696994114448476, 'epoch': 0.23}
# {'loss': 1.324, 'grad_norm': 2.0625, 'learning_rate': 0.00023696148894029079, 'epoch': 0.23}
# {'loss': 1.1235, 'grad_norm': 0.8515625, 'learning_rate': 0.0002369530367360968, 'epoch': 0.23}
# {'loss': 1.1903, 'grad_norm': 0.8984375, 'learning_rate': 0.00023694458453190283, 'epoch': 0.23}
# {'loss': 1.1923, 'grad_norm': 1.0703125, 'learning_rate': 0.00023693613232770883, 'epoch': 0.23}
# {'loss': 1.1345, 'grad_norm': 1.0234375, 'learning_rate': 0.00023692768012351486, 'epoch': 0.23}
# {'loss': 1.2988, 'grad_norm': 0.78125, 'learning_rate': 0.00023691922791932088, 'epoch': 0.23}
# {'loss': 1.1401, 'grad_norm': 0.7890625, 'learning_rate': 0.0002369107757151269, 'epoch': 0.23}
# {'loss': 1.1501, 'grad_norm': 1.015625, 'learning_rate': 0.0002369023235109329, 'epoch': 0.23}
# {'loss': 1.2152, 'grad_norm': 1.1171875, 'learning_rate': 0.00023689387130673893, 'epoch': 0.23}
# {'loss': 1.0578, 'grad_norm': 1.421875, 'learning_rate': 0.00023688541910254492, 'epoch': 0.23}
# {'loss': 1.2189, 'grad_norm': 1.171875, 'learning_rate': 0.00023687696689835095, 'epoch': 0.23}
# {'loss': 1.2276, 'grad_norm': 0.8828125, 'learning_rate': 0.00023686851469415697, 'epoch': 0.23}
# {'loss': 1.1686, 'grad_norm': 0.9375, 'learning_rate': 0.00023686006248996297, 'epoch': 0.23}
# {'loss': 1.2106, 'grad_norm': 0.96484375, 'learning_rate': 0.000236851610285769, 'epoch': 0.23}
# {'loss': 1.0405, 'grad_norm': 0.6796875, 'learning_rate': 0.00023684315808157502, 'epoch': 0.23}
# {'loss': 1.2225, 'grad_norm': 1.3984375, 'learning_rate': 0.00023683470587738104, 'epoch': 0.23}
# {'loss': 1.0762, 'grad_norm': 1.1953125, 'learning_rate': 0.00023682625367318704, 'epoch': 0.23}
# {'loss': 1.245, 'grad_norm': 1.046875, 'learning_rate': 0.00023681780146899307, 'epoch': 0.23}
# {'loss': 1.277, 'grad_norm': 0.796875, 'learning_rate': 0.0002368093492647991, 'epoch': 0.23}
# {'loss': 1.1279, 'grad_norm': 1.3359375, 'learning_rate': 0.00023680089706060512, 'epoch': 0.23}
# {'loss': 1.2231, 'grad_norm': 1.1796875, 'learning_rate': 0.0002367924448564111, 'epoch': 0.23}
# {'loss': 1.0708, 'grad_norm': 0.76953125, 'learning_rate': 0.00023678399265221714, 'epoch': 0.23}
# {'loss': 1.1904, 'grad_norm': 1.0390625, 'learning_rate': 0.00023677554044802316, 'epoch': 0.23}
# {'loss': 1.1445, 'grad_norm': 0.8828125, 'learning_rate': 0.00023676708824382916, 'epoch': 0.23}
# {'loss': 1.1985, 'grad_norm': 1.1953125, 'learning_rate': 0.00023675863603963518, 'epoch': 0.23}
# {'loss': 1.226, 'grad_norm': 0.9375, 'learning_rate': 0.00023675018383544118, 'epoch': 0.23}
# {'loss': 1.1587, 'grad_norm': 0.8359375, 'learning_rate': 0.0002367417316312472, 'epoch': 0.23}
# {'loss': 1.1922, 'grad_norm': 1.09375, 'learning_rate': 0.00023673327942705323, 'epoch': 0.23}
# {'loss': 1.1313, 'grad_norm': 0.72265625, 'learning_rate': 0.00023672482722285926, 'epoch': 0.23}
# {'loss': 1.0555, 'grad_norm': 0.201171875, 'learning_rate': 0.00023671637501866525, 'epoch': 0.23}
# {'loss': 1.1514, 'grad_norm': 1.0078125, 'learning_rate': 0.00023670792281447128, 'epoch': 0.23}
# {'loss': 1.107, 'grad_norm': 0.7421875, 'learning_rate': 0.0002366994706102773, 'epoch': 0.23}
# {'loss': 1.1514, 'grad_norm': 0.9140625, 'learning_rate': 0.00023669101840608333, 'epoch': 0.23}
# {'loss': 1.1687, 'grad_norm': 0.91015625, 'learning_rate': 0.00023668256620188932, 'epoch': 0.23}
# {'loss': 1.1523, 'grad_norm': 0.79296875, 'learning_rate': 0.00023667411399769535, 'epoch': 0.23}
# {'loss': 1.1822, 'grad_norm': 1.5703125, 'learning_rate': 0.00023666566179350137, 'epoch': 0.23}
# {'loss': 1.0381, 'grad_norm': 0.7109375, 'learning_rate': 0.0002366572095893074, 'epoch': 0.23}
# {'loss': 1.0163, 'grad_norm': 0.921875, 'learning_rate': 0.0002366487573851134, 'epoch': 0.23}
# {'loss': 1.2509, 'grad_norm': 0.65625, 'learning_rate': 0.0002366403051809194, 'epoch': 0.23}
# {'loss': 1.2182, 'grad_norm': 1.5390625, 'learning_rate': 0.00023663185297672542, 'epoch': 0.23}
# {'loss': 1.192, 'grad_norm': 0.87890625, 'learning_rate': 0.00023662340077253144, 'epoch': 0.23}
# {'loss': 1.2503, 'grad_norm': 0.984375, 'learning_rate': 0.00023661494856833747, 'epoch': 0.23}
# {'loss': 1.1151, 'grad_norm': 0.90625, 'learning_rate': 0.00023660649636414346, 'epoch': 0.23}
# {'loss': 1.1737, 'grad_norm': 0.9765625, 'learning_rate': 0.0002365980441599495, 'epoch': 0.24}
# {'loss': 1.1759, 'grad_norm': 1.515625, 'learning_rate': 0.0002365895919557555, 'epoch': 0.24}
# {'loss': 1.3203, 'grad_norm': 1.1328125, 'learning_rate': 0.00023658113975156154, 'epoch': 0.24}
# {'loss': 1.1344, 'grad_norm': 0.70703125, 'learning_rate': 0.00023657268754736756, 'epoch': 0.24}
# {'loss': 1.1497, 'grad_norm': 1.40625, 'learning_rate': 0.00023656423534317356, 'epoch': 0.24}
# {'loss': 1.1664, 'grad_norm': 0.82421875, 'learning_rate': 0.00023655578313897958, 'epoch': 0.24}
# {'loss': 1.0536, 'grad_norm': 1.484375, 'learning_rate': 0.0002365473309347856, 'epoch': 0.24}
# {'loss': 1.2972, 'grad_norm': 1.125, 'learning_rate': 0.00023653887873059163, 'epoch': 0.24}
# {'loss': 1.1322, 'grad_norm': 0.79296875, 'learning_rate': 0.0002365304265263976, 'epoch': 0.24}
# {'loss': 1.1125, 'grad_norm': 0.9375, 'learning_rate': 0.00023652197432220363, 'epoch': 0.24}
# {'loss': 1.1031, 'grad_norm': 0.86328125, 'learning_rate': 0.00023651352211800965, 'epoch': 0.24}
# {'loss': 1.1724, 'grad_norm': 0.96484375, 'learning_rate': 0.00023650506991381568, 'epoch': 0.24}
# {'loss': 1.2356, 'grad_norm': 1.0859375, 'learning_rate': 0.00023649661770962167, 'epoch': 0.24}
# {'loss': 1.2986, 'grad_norm': 0.84765625, 'learning_rate': 0.0002364881655054277, 'epoch': 0.24}
# {'loss': 1.2513, 'grad_norm': 0.859375, 'learning_rate': 0.00023647971330123372, 'epoch': 0.24}
# {'loss': 1.2538, 'grad_norm': 0.984375, 'learning_rate': 0.00023647126109703975, 'epoch': 0.24}
# {'loss': 1.0325, 'grad_norm': 0.62109375, 'learning_rate': 0.00023646280889284577, 'epoch': 0.24}
# {'loss': 1.2609, 'grad_norm': 0.99609375, 'learning_rate': 0.00023645435668865177, 'epoch': 0.24}
# {'loss': 1.2007, 'grad_norm': 0.8515625, 'learning_rate': 0.0002364459044844578, 'epoch': 0.24}
# {'loss': 1.1495, 'grad_norm': 1.1328125, 'learning_rate': 0.00023643745228026382, 'epoch': 0.24}
# {'loss': 1.1886, 'grad_norm': 0.94921875, 'learning_rate': 0.00023642900007606984, 'epoch': 0.24}
# {'loss': 1.0347, 'grad_norm': 1.125, 'learning_rate': 0.0002364205478718758, 'epoch': 0.24}
# {'loss': 1.3583, 'grad_norm': 0.90234375, 'learning_rate': 0.00023641209566768184, 'epoch': 0.24}
# {'loss': 1.2109, 'grad_norm': 0.92578125, 'learning_rate': 0.00023640364346348786, 'epoch': 0.24}
# {'loss': 1.2264, 'grad_norm': 1.1171875, 'learning_rate': 0.0002363951912592939, 'epoch': 0.24}
# {'loss': 1.3025, 'grad_norm': 0.9921875, 'learning_rate': 0.00023638673905509988, 'epoch': 0.24}
# {'loss': 1.0168, 'grad_norm': 1.03125, 'learning_rate': 0.0002363782868509059, 'epoch': 0.24}
# {'loss': 1.277, 'grad_norm': 1.3984375, 'learning_rate': 0.00023636983464671193, 'epoch': 0.24}
# {'loss': 1.1224, 'grad_norm': 0.84765625, 'learning_rate': 0.00023636138244251796, 'epoch': 0.24}
# {'loss': 1.0413, 'grad_norm': 1.1015625, 'learning_rate': 0.00023635293023832398, 'epoch': 0.24}
# {'loss': 1.2547, 'grad_norm': 0.98046875, 'learning_rate': 0.00023634447803412998, 'epoch': 0.24}
# {'loss': 1.1259, 'grad_norm': 0.9921875, 'learning_rate': 0.000236336025829936, 'epoch': 0.24}
# {'loss': 1.266, 'grad_norm': 0.93359375, 'learning_rate': 0.00023632757362574203, 'epoch': 0.24}
# {'loss': 1.2105, 'grad_norm': 0.80859375, 'learning_rate': 0.00023631912142154805, 'epoch': 0.24}
# {'loss': 1.2149, 'grad_norm': 0.953125, 'learning_rate': 0.00023631066921735402, 'epoch': 0.24}
# {'loss': 1.1881, 'grad_norm': 0.7734375, 'learning_rate': 0.00023630221701316005, 'epoch': 0.24}
# {'loss': 1.1143, 'grad_norm': 1.390625, 'learning_rate': 0.00023629376480896607, 'epoch': 0.24}
# {'loss': 1.1823, 'grad_norm': 0.9609375, 'learning_rate': 0.0002362853126047721, 'epoch': 0.24}
# {'loss': 1.1194, 'grad_norm': 0.7734375, 'learning_rate': 0.0002362768604005781, 'epoch': 0.24}
# {'loss': 1.1123, 'grad_norm': 0.74609375, 'learning_rate': 0.00023626840819638412, 'epoch': 0.24}
# {'loss': 1.2663, 'grad_norm': 0.75, 'learning_rate': 0.00023625995599219014, 'epoch': 0.24}
# {'loss': 1.1285, 'grad_norm': 0.9765625, 'learning_rate': 0.00023625150378799617, 'epoch': 0.24}
# {'loss': 1.2621, 'grad_norm': 0.97265625, 'learning_rate': 0.0002362430515838022, 'epoch': 0.24}
# {'loss': 1.2113, 'grad_norm': 0.875, 'learning_rate': 0.0002362345993796082, 'epoch': 0.24}
# {'loss': 1.1925, 'grad_norm': 0.9296875, 'learning_rate': 0.00023622614717541421, 'epoch': 0.24}
# {'loss': 1.2298, 'grad_norm': 0.796875, 'learning_rate': 0.00023621769497122024, 'epoch': 0.24}
# {'loss': 1.1206, 'grad_norm': 0.953125, 'learning_rate': 0.00023620924276702626, 'epoch': 0.24}
# {'loss': 1.2035, 'grad_norm': 1.5546875, 'learning_rate': 0.00023620079056283223, 'epoch': 0.24}
# {'loss': 1.2353, 'grad_norm': 0.73046875, 'learning_rate': 0.00023619233835863826, 'epoch': 0.24}
# {'loss': 1.0824, 'grad_norm': 1.140625, 'learning_rate': 0.00023618388615444428, 'epoch': 0.24}
# {'loss': 1.1112, 'grad_norm': 0.8671875, 'learning_rate': 0.0002361754339502503, 'epoch': 0.24}
# {'loss': 1.076, 'grad_norm': 0.37890625, 'learning_rate': 0.0002361669817460563, 'epoch': 0.24}
# {'loss': 1.3555, 'grad_norm': 0.7265625, 'learning_rate': 0.00023615852954186233, 'epoch': 0.24}
# {'loss': 1.0991, 'grad_norm': 0.921875, 'learning_rate': 0.00023615007733766835, 'epoch': 0.24}
# {'loss': 1.0775, 'grad_norm': 0.9609375, 'learning_rate': 0.00023614162513347438, 'epoch': 0.24}
# {'loss': 1.2904, 'grad_norm': 0.6171875, 'learning_rate': 0.0002361331729292804, 'epoch': 0.24}
# {'loss': 1.1178, 'grad_norm': 1.2265625, 'learning_rate': 0.0002361247207250864, 'epoch': 0.24}
# {'loss': 1.3069, 'grad_norm': 0.89453125, 'learning_rate': 0.00023611626852089243, 'epoch': 0.24}
# {'loss': 1.1416, 'grad_norm': 0.8671875, 'learning_rate': 0.00023610781631669845, 'epoch': 0.24}
# {'loss': 1.1232, 'grad_norm': 1.4609375, 'learning_rate': 0.00023609936411250447, 'epoch': 0.24}
# {'loss': 1.1783, 'grad_norm': 1.1953125, 'learning_rate': 0.00023609091190831044, 'epoch': 0.24}
# {'loss': 1.0529, 'grad_norm': 0.298828125, 'learning_rate': 0.00023608245970411647, 'epoch': 0.24}
# {'loss': 1.3452, 'grad_norm': 0.87890625, 'learning_rate': 0.0002360740074999225, 'epoch': 0.24}
# {'loss': 1.1808, 'grad_norm': 0.82421875, 'learning_rate': 0.00023606555529572852, 'epoch': 0.24}
# {'loss': 1.2231, 'grad_norm': 0.9765625, 'learning_rate': 0.00023605710309153454, 'epoch': 0.24}
# {'loss': 1.1885, 'grad_norm': 1.03125, 'learning_rate': 0.00023604865088734054, 'epoch': 0.24}
# {'loss': 1.1551, 'grad_norm': 1.5625, 'learning_rate': 0.00023604019868314656, 'epoch': 0.24}
# {'loss': 1.3058, 'grad_norm': 1.171875, 'learning_rate': 0.0002360317464789526, 'epoch': 0.24}
# {'loss': 1.1874, 'grad_norm': 0.8359375, 'learning_rate': 0.00023602329427475861, 'epoch': 0.24}
# {'loss': 1.1293, 'grad_norm': 1.109375, 'learning_rate': 0.0002360148420705646, 'epoch': 0.24}
# {'loss': 1.14, 'grad_norm': 1.1328125, 'learning_rate': 0.00023600638986637064, 'epoch': 0.24}
# {'loss': 1.1308, 'grad_norm': 1.234375, 'learning_rate': 0.00023599793766217666, 'epoch': 0.24}
# {'loss': 1.2398, 'grad_norm': 0.98828125, 'learning_rate': 0.00023598948545798268, 'epoch': 0.24}
# {'loss': 1.1913, 'grad_norm': 1.0078125, 'learning_rate': 0.00023598103325378866, 'epoch': 0.24}
# {'loss': 1.1238, 'grad_norm': 0.94921875, 'learning_rate': 0.00023597258104959468, 'epoch': 0.24}
# {'loss': 1.1121, 'grad_norm': 0.79296875, 'learning_rate': 0.0002359641288454007, 'epoch': 0.24}
# {'loss': 1.0534, 'grad_norm': 1.015625, 'learning_rate': 0.00023595567664120673, 'epoch': 0.24}
# {'loss': 1.2688, 'grad_norm': 1.1796875, 'learning_rate': 0.00023594722443701275, 'epoch': 0.24}
# {'loss': 1.186, 'grad_norm': 0.8359375, 'learning_rate': 0.00023593877223281875, 'epoch': 0.24}
# {'loss': 1.1377, 'grad_norm': 0.8515625, 'learning_rate': 0.00023593032002862478, 'epoch': 0.24}
# {'loss': 1.3147, 'grad_norm': 0.73828125, 'learning_rate': 0.0002359218678244308, 'epoch': 0.24}
# {'loss': 1.104, 'grad_norm': 0.271484375, 'learning_rate': 0.00023591341562023682, 'epoch': 0.24}
# {'loss': 1.2883, 'grad_norm': 0.78125, 'learning_rate': 0.00023590496341604282, 'epoch': 0.24}
# {'loss': 1.2252, 'grad_norm': 0.80078125, 'learning_rate': 0.00023589651121184885, 'epoch': 0.24}
# {'loss': 1.1794, 'grad_norm': 0.95703125, 'learning_rate': 0.00023588805900765487, 'epoch': 0.24}
# {'loss': 1.1286, 'grad_norm': 0.99609375, 'learning_rate': 0.0002358796068034609, 'epoch': 0.24}
# {'loss': 1.1512, 'grad_norm': 1.25, 'learning_rate': 0.00023587115459926687, 'epoch': 0.24}
# {'loss': 1.226, 'grad_norm': 0.875, 'learning_rate': 0.0002358627023950729, 'epoch': 0.24}
# {'loss': 1.2191, 'grad_norm': 0.80859375, 'learning_rate': 0.00023585425019087891, 'epoch': 0.24}
# {'loss': 1.1598, 'grad_norm': 1.2578125, 'learning_rate': 0.00023584579798668494, 'epoch': 0.24}
# {'loss': 1.2463, 'grad_norm': 1.1953125, 'learning_rate': 0.00023583734578249096, 'epoch': 0.24}
# {'loss': 1.002, 'grad_norm': 0.80859375, 'learning_rate': 0.00023582889357829696, 'epoch': 0.24}
# {'loss': 1.1914, 'grad_norm': 0.796875, 'learning_rate': 0.00023582044137410299, 'epoch': 0.24}
# {'loss': 1.1012, 'grad_norm': 0.87109375, 'learning_rate': 0.000235811989169909, 'epoch': 0.24}
# {'loss': 1.1335, 'grad_norm': 1.171875, 'learning_rate': 0.00023580353696571503, 'epoch': 0.24}
# {'loss': 1.2178, 'grad_norm': 0.9765625, 'learning_rate': 0.00023579508476152103, 'epoch': 0.24}
# {'loss': 1.0649, 'grad_norm': 0.9140625, 'learning_rate': 0.00023578663255732706, 'epoch': 0.24}
# {'loss': 1.2667, 'grad_norm': 0.71484375, 'learning_rate': 0.00023577818035313308, 'epoch': 0.24}
# {'loss': 1.1292, 'grad_norm': 0.76953125, 'learning_rate': 0.0002357697281489391, 'epoch': 0.24}
# {'loss': 1.2082, 'grad_norm': 0.84375, 'learning_rate': 0.00023576127594474508, 'epoch': 0.24}
# {'loss': 1.1455, 'grad_norm': 0.8359375, 'learning_rate': 0.0002357528237405511, 'epoch': 0.24}
# {'loss': 1.1152, 'grad_norm': 1.0390625, 'learning_rate': 0.00023574437153635713, 'epoch': 0.24}
# {'loss': 1.2082, 'grad_norm': 0.99609375, 'learning_rate': 0.00023573591933216315, 'epoch': 0.24}
# {'loss': 1.109, 'grad_norm': 0.71875, 'learning_rate': 0.00023572746712796917, 'epoch': 0.24}
# {'loss': 1.1221, 'grad_norm': 0.87890625, 'learning_rate': 0.00023571901492377517, 'epoch': 0.24}
# {'loss': 1.2053, 'grad_norm': 0.875, 'learning_rate': 0.0002357105627195812, 'epoch': 0.24}
# {'loss': 1.032, 'grad_norm': 0.255859375, 'learning_rate': 0.00023570211051538722, 'epoch': 0.24}
# {'loss': 1.243, 'grad_norm': 0.9453125, 'learning_rate': 0.00023569365831119325, 'epoch': 0.24}
# {'loss': 1.0589, 'grad_norm': 0.8359375, 'learning_rate': 0.00023568520610699924, 'epoch': 0.24}
# {'loss': 1.1661, 'grad_norm': 0.796875, 'learning_rate': 0.00023567675390280527, 'epoch': 0.24}
# {'loss': 1.2195, 'grad_norm': 0.890625, 'learning_rate': 0.0002356683016986113, 'epoch': 0.24}
# {'loss': 1.016, 'grad_norm': 0.93359375, 'learning_rate': 0.00023565984949441732, 'epoch': 0.24}
# {'loss': 1.2441, 'grad_norm': 0.80859375, 'learning_rate': 0.0002356513972902233, 'epoch': 0.24}
# {'loss': 1.134, 'grad_norm': 0.7578125, 'learning_rate': 0.0002356429450860293, 'epoch': 0.24}
# {'loss': 1.0317, 'grad_norm': 1.3828125, 'learning_rate': 0.00023563449288183534, 'epoch': 0.24}
# {'loss': 1.0948, 'grad_norm': 0.89453125, 'learning_rate': 0.00023562604067764136, 'epoch': 0.24}
# {'loss': 1.2085, 'grad_norm': 0.84765625, 'learning_rate': 0.00023561758847344738, 'epoch': 0.24}
# {'loss': 1.2963, 'grad_norm': 1.109375, 'learning_rate': 0.00023560913626925338, 'epoch': 0.24}
# {'loss': 1.1815, 'grad_norm': 0.65625, 'learning_rate': 0.0002356006840650594, 'epoch': 0.24}
# {'loss': 1.1258, 'grad_norm': 0.80859375, 'learning_rate': 0.00023559223186086543, 'epoch': 0.24}
# {'loss': 1.1962, 'grad_norm': 0.78125, 'learning_rate': 0.00023558377965667146, 'epoch': 0.24}
# {'loss': 0.998, 'grad_norm': 1.2265625, 'learning_rate': 0.00023557532745247745, 'epoch': 0.24}
# {'loss': 1.2319, 'grad_norm': 1.140625, 'learning_rate': 0.00023556687524828348, 'epoch': 0.24}
# {'loss': 1.034, 'grad_norm': 0.8828125, 'learning_rate': 0.0002355584230440895, 'epoch': 0.24}
# {'loss': 1.2404, 'grad_norm': 0.84375, 'learning_rate': 0.00023554997083989553, 'epoch': 0.24}
# {'loss': 1.2069, 'grad_norm': 1.0234375, 'learning_rate': 0.00023554151863570155, 'epoch': 0.24}
# {'loss': 1.0613, 'grad_norm': 0.66015625, 'learning_rate': 0.00023553306643150752, 'epoch': 0.24}
# {'loss': 1.2778, 'grad_norm': 0.859375, 'learning_rate': 0.00023552461422731355, 'epoch': 0.24}
# {'loss': 1.0667, 'grad_norm': 0.921875, 'learning_rate': 0.00023551616202311957, 'epoch': 0.24}
# {'loss': 1.1071, 'grad_norm': 0.9921875, 'learning_rate': 0.0002355077098189256, 'epoch': 0.24}
# {'loss': 1.2484, 'grad_norm': 0.84765625, 'learning_rate': 0.0002354992576147316, 'epoch': 0.24}
# {'loss': 1.1361, 'grad_norm': 2.453125, 'learning_rate': 0.00023549080541053762, 'epoch': 0.24}
# {'loss': 1.2572, 'grad_norm': 0.93359375, 'learning_rate': 0.00023548235320634364, 'epoch': 0.24}
# {'loss': 1.1308, 'grad_norm': 1.296875, 'learning_rate': 0.00023547390100214967, 'epoch': 0.24}
# {'loss': 1.1254, 'grad_norm': 1.328125, 'learning_rate': 0.00023546544879795566, 'epoch': 0.24}
# {'loss': 1.0854, 'grad_norm': 0.8671875, 'learning_rate': 0.0002354569965937617, 'epoch': 0.24}
# {'loss': 1.1121, 'grad_norm': 1.6875, 'learning_rate': 0.0002354485443895677, 'epoch': 0.24}
# {'loss': 1.3018, 'grad_norm': 1.09375, 'learning_rate': 0.00023544009218537374, 'epoch': 0.24}
# {'loss': 1.0427, 'grad_norm': 0.78125, 'learning_rate': 0.00023543163998117976, 'epoch': 0.24}
# {'loss': 1.169, 'grad_norm': 0.94140625, 'learning_rate': 0.00023542318777698573, 'epoch': 0.24}
# {'loss': 1.2884, 'grad_norm': 1.03125, 'learning_rate': 0.00023541473557279176, 'epoch': 0.24}
# {'loss': 1.0591, 'grad_norm': 1.2109375, 'learning_rate': 0.00023540628336859778, 'epoch': 0.24}
# {'loss': 1.2547, 'grad_norm': 1.3828125, 'learning_rate': 0.0002353978311644038, 'epoch': 0.24}
# {'loss': 1.1326, 'grad_norm': 0.79296875, 'learning_rate': 0.0002353893789602098, 'epoch': 0.24}
# {'loss': 1.0555, 'grad_norm': 0.96875, 'learning_rate': 0.00023538092675601583, 'epoch': 0.24}
# {'loss': 1.1176, 'grad_norm': 0.70703125, 'learning_rate': 0.00023537247455182185, 'epoch': 0.24}
# {'loss': 1.1193, 'grad_norm': 0.734375, 'learning_rate': 0.00023536402234762788, 'epoch': 0.24}
# {'loss': 1.2859, 'grad_norm': 1.15625, 'learning_rate': 0.00023535557014343387, 'epoch': 0.24}
# {'loss': 1.0901, 'grad_norm': 1.109375, 'learning_rate': 0.0002353471179392399, 'epoch': 0.24}
# {'loss': 1.2555, 'grad_norm': 0.87109375, 'learning_rate': 0.00023533866573504592, 'epoch': 0.24}
# {'loss': 1.2802, 'grad_norm': 0.96875, 'learning_rate': 0.00023533021353085195, 'epoch': 0.24}
# {'loss': 1.1264, 'grad_norm': 1.1015625, 'learning_rate': 0.00023532176132665797, 'epoch': 0.24}
# {'loss': 1.2145, 'grad_norm': 1.1015625, 'learning_rate': 0.00023531330912246394, 'epoch': 0.24}
# {'loss': 1.1467, 'grad_norm': 0.73046875, 'learning_rate': 0.00023530485691826997, 'epoch': 0.24}
# {'loss': 1.1696, 'grad_norm': 1.109375, 'learning_rate': 0.000235296404714076, 'epoch': 0.24}
# {'loss': 1.2321, 'grad_norm': 0.9609375, 'learning_rate': 0.00023528795250988202, 'epoch': 0.24}
# {'loss': 1.1512, 'grad_norm': 1.484375, 'learning_rate': 0.000235279500305688, 'epoch': 0.24}
# {'loss': 1.1558, 'grad_norm': 1.078125, 'learning_rate': 0.00023527104810149404, 'epoch': 0.24}
# {'loss': 1.1664, 'grad_norm': 0.80078125, 'learning_rate': 0.00023526259589730006, 'epoch': 0.24}
# {'loss': 1.134, 'grad_norm': 1.03125, 'learning_rate': 0.0002352541436931061, 'epoch': 0.24}
# {'loss': 1.2147, 'grad_norm': 0.83203125, 'learning_rate': 0.00023524569148891208, 'epoch': 0.24}
# {'loss': 1.1273, 'grad_norm': 1.0, 'learning_rate': 0.0002352372392847181, 'epoch': 0.24}
# {'loss': 1.3923, 'grad_norm': 1.296875, 'learning_rate': 0.00023522878708052413, 'epoch': 0.24}
# {'loss': 1.1105, 'grad_norm': 0.796875, 'learning_rate': 0.00023522033487633016, 'epoch': 0.24}
# {'loss': 1.2237, 'grad_norm': 0.8984375, 'learning_rate': 0.00023521188267213618, 'epoch': 0.24}
# {'loss': 1.2741, 'grad_norm': 0.890625, 'learning_rate': 0.00023520343046794218, 'epoch': 0.24}
# {'loss': 1.0694, 'grad_norm': 5.59375, 'learning_rate': 0.00023519497826374818, 'epoch': 0.24}
# {'loss': 1.2872, 'grad_norm': 0.890625, 'learning_rate': 0.0002351865260595542, 'epoch': 0.24}
# {'loss': 1.1679, 'grad_norm': 0.76953125, 'learning_rate': 0.00023517807385536023, 'epoch': 0.24}
# {'loss': 1.2772, 'grad_norm': 2.140625, 'learning_rate': 0.00023516962165116622, 'epoch': 0.24}
# {'loss': 1.2295, 'grad_norm': 1.1015625, 'learning_rate': 0.00023516116944697225, 'epoch': 0.24}
# {'loss': 1.0043, 'grad_norm': 1.4140625, 'learning_rate': 0.00023515271724277827, 'epoch': 0.24}
# {'loss': 1.3064, 'grad_norm': 1.0234375, 'learning_rate': 0.0002351442650385843, 'epoch': 0.24}
# {'loss': 1.1436, 'grad_norm': 0.94140625, 'learning_rate': 0.0002351358128343903, 'epoch': 0.24}
# {'loss': 1.1467, 'grad_norm': 1.2890625, 'learning_rate': 0.00023512736063019632, 'epoch': 0.24}
# {'loss': 1.0732, 'grad_norm': 0.8125, 'learning_rate': 0.00023511890842600234, 'epoch': 0.24}
# {'loss': 1.0431, 'grad_norm': 0.78515625, 'learning_rate': 0.00023511045622180837, 'epoch': 0.24}
# {'loss': 1.2767, 'grad_norm': 0.84375, 'learning_rate': 0.0002351020040176144, 'epoch': 0.24}
# {'loss': 1.2003, 'grad_norm': 0.87109375, 'learning_rate': 0.0002350935518134204, 'epoch': 0.24}
# {'loss': 1.1625, 'grad_norm': 1.3359375, 'learning_rate': 0.00023508509960922642, 'epoch': 0.24}
# {'loss': 1.1889, 'grad_norm': 0.91015625, 'learning_rate': 0.0002350766474050324, 'epoch': 0.24}
# {'loss': 1.1421, 'grad_norm': 2.046875, 'learning_rate': 0.00023506819520083844, 'epoch': 0.24}
# {'loss': 1.3766, 'grad_norm': 0.6484375, 'learning_rate': 0.00023505974299664443, 'epoch': 0.24}
# {'loss': 1.191, 'grad_norm': 0.77734375, 'learning_rate': 0.00023505129079245046, 'epoch': 0.24}
# {'loss': 1.179, 'grad_norm': 1.2265625, 'learning_rate': 0.00023504283858825648, 'epoch': 0.24}
# {'loss': 1.259, 'grad_norm': 0.6796875, 'learning_rate': 0.0002350343863840625, 'epoch': 0.24}
# {'loss': 1.0017, 'grad_norm': 0.91796875, 'learning_rate': 0.00023502593417986853, 'epoch': 0.24}
# {'loss': 1.2741, 'grad_norm': 0.8984375, 'learning_rate': 0.00023501748197567453, 'epoch': 0.24}
# {'loss': 1.1261, 'grad_norm': 0.75, 'learning_rate': 0.00023500902977148055, 'epoch': 0.24}
# {'loss': 1.1506, 'grad_norm': 1.0234375, 'learning_rate': 0.00023500057756728658, 'epoch': 0.24}
# {'loss': 1.2119, 'grad_norm': 0.671875, 'learning_rate': 0.0002349921253630926, 'epoch': 0.24}
# {'loss': 1.0832, 'grad_norm': 0.96875, 'learning_rate': 0.0002349836731588986, 'epoch': 0.24}
# {'loss': 1.2931, 'grad_norm': 0.89453125, 'learning_rate': 0.00023497522095470463, 'epoch': 0.24}
# {'loss': 1.1761, 'grad_norm': 0.6484375, 'learning_rate': 0.00023496676875051065, 'epoch': 0.24}
# {'loss': 1.1451, 'grad_norm': 0.859375, 'learning_rate': 0.00023495831654631665, 'epoch': 0.24}
# {'loss': 1.2757, 'grad_norm': 0.93359375, 'learning_rate': 0.00023494986434212264, 'epoch': 0.24}
# {'loss': 1.0469, 'grad_norm': 0.244140625, 'learning_rate': 0.00023494141213792867, 'epoch': 0.24}
# {'loss': 1.2829, 'grad_norm': 0.78125, 'learning_rate': 0.0002349329599337347, 'epoch': 0.24}
# {'loss': 1.0946, 'grad_norm': 0.77734375, 'learning_rate': 0.00023492450772954072, 'epoch': 0.24}
# {'loss': 1.1792, 'grad_norm': 0.8515625, 'learning_rate': 0.00023491605552534674, 'epoch': 0.24}
# {'loss': 1.2105, 'grad_norm': 0.76171875, 'learning_rate': 0.00023490760332115274, 'epoch': 0.24}
# {'loss': 1.2079, 'grad_norm': 0.6015625, 'learning_rate': 0.00023489915111695876, 'epoch': 0.24}
# {'loss': 1.2675, 'grad_norm': 1.1875, 'learning_rate': 0.0002348906989127648, 'epoch': 0.24}
# {'loss': 1.2326, 'grad_norm': 0.7578125, 'learning_rate': 0.00023488224670857081, 'epoch': 0.24}
# {'loss': 1.0595, 'grad_norm': 0.84765625, 'learning_rate': 0.0002348737945043768, 'epoch': 0.24}
# {'loss': 1.2103, 'grad_norm': 0.91015625, 'learning_rate': 0.00023486534230018284, 'epoch': 0.24}
# {'loss': 1.0849, 'grad_norm': 1.109375, 'learning_rate': 0.00023485689009598886, 'epoch': 0.24}
# {'loss': 1.2656, 'grad_norm': 0.8984375, 'learning_rate': 0.00023484843789179489, 'epoch': 0.24}
# {'loss': 1.1812, 'grad_norm': 0.78515625, 'learning_rate': 0.00023483998568760086, 'epoch': 0.24}
# {'loss': 1.2246, 'grad_norm': 1.1484375, 'learning_rate': 0.00023483153348340688, 'epoch': 0.24}
# {'loss': 1.1906, 'grad_norm': 0.86328125, 'learning_rate': 0.0002348230812792129, 'epoch': 0.24}
# {'loss': 0.9897, 'grad_norm': 0.5546875, 'learning_rate': 0.00023481462907501893, 'epoch': 0.24}
# {'loss': 1.1769, 'grad_norm': 0.9921875, 'learning_rate': 0.00023480617687082495, 'epoch': 0.24}
# {'loss': 1.0961, 'grad_norm': 0.9140625, 'learning_rate': 0.00023479772466663095, 'epoch': 0.24}
# {'loss': 1.1866, 'grad_norm': 0.828125, 'learning_rate': 0.00023478927246243698, 'epoch': 0.24}
# {'loss': 1.1513, 'grad_norm': 0.796875, 'learning_rate': 0.000234780820258243, 'epoch': 0.24}
# {'loss': 1.1072, 'grad_norm': 1.328125, 'learning_rate': 0.00023477236805404902, 'epoch': 0.24}
# {'loss': 1.2867, 'grad_norm': 1.1015625, 'learning_rate': 0.00023476391584985502, 'epoch': 0.24}
# {'loss': 1.1356, 'grad_norm': 0.80859375, 'learning_rate': 0.00023475546364566105, 'epoch': 0.24}
# {'loss': 1.2242, 'grad_norm': 0.7265625, 'learning_rate': 0.00023474701144146707, 'epoch': 0.24}
# {'loss': 1.0515, 'grad_norm': 0.94921875, 'learning_rate': 0.0002347385592372731, 'epoch': 0.24}
# {'loss': 1.1532, 'grad_norm': 1.0625, 'learning_rate': 0.00023473010703307907, 'epoch': 0.24}
# {'loss': 1.277, 'grad_norm': 1.1796875, 'learning_rate': 0.0002347216548288851, 'epoch': 0.24}
# {'loss': 1.1134, 'grad_norm': 0.7734375, 'learning_rate': 0.00023471320262469111, 'epoch': 0.24}
# {'loss': 1.1317, 'grad_norm': 0.94140625, 'learning_rate': 0.00023470475042049714, 'epoch': 0.24}
# {'loss': 1.2451, 'grad_norm': 0.8125, 'learning_rate': 0.00023469629821630316, 'epoch': 0.24}
# {'loss': 1.1756, 'grad_norm': 1.421875, 'learning_rate': 0.00023468784601210916, 'epoch': 0.24}
# {'loss': 1.2425, 'grad_norm': 0.765625, 'learning_rate': 0.00023467939380791519, 'epoch': 0.24}
# {'loss': 1.1338, 'grad_norm': 0.68359375, 'learning_rate': 0.0002346709416037212, 'epoch': 0.24}
# {'loss': 1.0647, 'grad_norm': 1.8125, 'learning_rate': 0.00023466248939952724, 'epoch': 0.24}
# {'loss': 1.1715, 'grad_norm': 0.7265625, 'learning_rate': 0.00023465403719533323, 'epoch': 0.24}
# {'loss': 1.1505, 'grad_norm': 1.6171875, 'learning_rate': 0.00023464558499113926, 'epoch': 0.24}
# {'loss': 1.2728, 'grad_norm': 1.1171875, 'learning_rate': 0.00023463713278694528, 'epoch': 0.24}
# {'loss': 1.1413, 'grad_norm': 0.92578125, 'learning_rate': 0.0002346286805827513, 'epoch': 0.24}
# {'loss': 1.1503, 'grad_norm': 0.9609375, 'learning_rate': 0.00023462022837855728, 'epoch': 0.24}
# {'loss': 1.04, 'grad_norm': 0.8203125, 'learning_rate': 0.0002346117761743633, 'epoch': 0.24}
# {'loss': 1.0826, 'grad_norm': 0.83203125, 'learning_rate': 0.00023460332397016933, 'epoch': 0.24}
# {'loss': 1.3472, 'grad_norm': 0.87890625, 'learning_rate': 0.00023459487176597535, 'epoch': 0.24}
# {'loss': 1.1355, 'grad_norm': 0.75390625, 'learning_rate': 0.00023458641956178137, 'epoch': 0.24}
# {'loss': 1.1252, 'grad_norm': 1.5859375, 'learning_rate': 0.00023457796735758737, 'epoch': 0.24}
# {'loss': 1.283, 'grad_norm': 0.87109375, 'learning_rate': 0.0002345695151533934, 'epoch': 0.24}
# {'loss': 1.0605, 'grad_norm': 0.94921875, 'learning_rate': 0.00023456106294919942, 'epoch': 0.24}
# {'loss': 1.2797, 'grad_norm': 0.875, 'learning_rate': 0.00023455261074500545, 'epoch': 0.24}
# {'loss': 1.0969, 'grad_norm': 0.94921875, 'learning_rate': 0.00023454415854081144, 'epoch': 0.24}
# {'loss': 1.0667, 'grad_norm': 0.890625, 'learning_rate': 0.00023453570633661747, 'epoch': 0.24}
# {'loss': 1.1944, 'grad_norm': 0.83203125, 'learning_rate': 0.0002345272541324235, 'epoch': 0.24}
# {'loss': 1.0881, 'grad_norm': 1.640625, 'learning_rate': 0.00023451880192822952, 'epoch': 0.24}
# {'loss': 1.2343, 'grad_norm': 0.921875, 'learning_rate': 0.00023451034972403554, 'epoch': 0.24}
# {'loss': 1.2042, 'grad_norm': 0.71484375, 'learning_rate': 0.0002345018975198415, 'epoch': 0.24}
# {'loss': 1.17, 'grad_norm': 1.5078125, 'learning_rate': 0.00023449344531564754, 'epoch': 0.24}
# {'loss': 1.2251, 'grad_norm': 0.80078125, 'learning_rate': 0.00023448499311145356, 'epoch': 0.24}
# {'loss': 1.1555, 'grad_norm': 1.6484375, 'learning_rate': 0.00023447654090725958, 'epoch': 0.24}
# {'loss': 1.2088, 'grad_norm': 0.98828125, 'learning_rate': 0.00023446808870306558, 'epoch': 0.24}
# {'loss': 1.1809, 'grad_norm': 0.96484375, 'learning_rate': 0.0002344596364988716, 'epoch': 0.24}
# {'loss': 1.1294, 'grad_norm': 0.859375, 'learning_rate': 0.00023445118429467763, 'epoch': 0.24}
# {'loss': 1.1994, 'grad_norm': 0.87109375, 'learning_rate': 0.00023444273209048366, 'epoch': 0.24}
# {'loss': 1.0189, 'grad_norm': 0.287109375, 'learning_rate': 0.00023443427988628965, 'epoch': 0.24}
# {'loss': 1.2866, 'grad_norm': 0.78515625, 'learning_rate': 0.00023442582768209568, 'epoch': 0.24}
# {'loss': 1.1687, 'grad_norm': 0.84765625, 'learning_rate': 0.0002344173754779017, 'epoch': 0.24}
# {'loss': 1.1508, 'grad_norm': 0.98046875, 'learning_rate': 0.00023440892327370773, 'epoch': 0.24}
# {'loss': 1.173, 'grad_norm': 1.1171875, 'learning_rate': 0.00023440047106951375, 'epoch': 0.24}
# {'loss': 1.1057, 'grad_norm': 0.9765625, 'learning_rate': 0.00023439201886531972, 'epoch': 0.24}
# {'loss': 1.1001, 'grad_norm': 0.84765625, 'learning_rate': 0.00023438356666112575, 'epoch': 0.24}
# {'loss': 1.1513, 'grad_norm': 0.890625, 'learning_rate': 0.00023437511445693177, 'epoch': 0.24}
# {'loss': 1.2181, 'grad_norm': 1.140625, 'learning_rate': 0.0002343666622527378, 'epoch': 0.24}
# {'loss': 1.2122, 'grad_norm': 0.828125, 'learning_rate': 0.0002343582100485438, 'epoch': 0.24}
# {'loss': 1.063, 'grad_norm': 1.0625, 'learning_rate': 0.00023434975784434982, 'epoch': 0.24}
# {'loss': 1.2431, 'grad_norm': 1.03125, 'learning_rate': 0.00023434130564015584, 'epoch': 0.24}
# {'loss': 1.1719, 'grad_norm': 0.74609375, 'learning_rate': 0.00023433285343596187, 'epoch': 0.24}
# {'loss': 1.1048, 'grad_norm': 1.3359375, 'learning_rate': 0.00023432440123176786, 'epoch': 0.24}
# {'loss': 1.1257, 'grad_norm': 0.7578125, 'learning_rate': 0.0002343159490275739, 'epoch': 0.24}
# {'loss': 1.0969, 'grad_norm': 1.3671875, 'learning_rate': 0.0002343074968233799, 'epoch': 0.24}
# {'loss': 1.1458, 'grad_norm': 1.15625, 'learning_rate': 0.00023429904461918594, 'epoch': 0.24}
# {'loss': 1.1329, 'grad_norm': 0.82421875, 'learning_rate': 0.00023429059241499196, 'epoch': 0.24}
# {'loss': 1.1872, 'grad_norm': 1.1171875, 'learning_rate': 0.00023428214021079793, 'epoch': 0.24}
# {'loss': 1.1312, 'grad_norm': 1.0078125, 'learning_rate': 0.00023427368800660396, 'epoch': 0.24}
# {'loss': 1.0466, 'grad_norm': 1.875, 'learning_rate': 0.00023426523580240998, 'epoch': 0.24}
# {'loss': 1.3207, 'grad_norm': 0.9921875, 'learning_rate': 0.000234256783598216, 'epoch': 0.24}
# {'loss': 1.0973, 'grad_norm': 0.8203125, 'learning_rate': 0.000234248331394022, 'epoch': 0.24}
# {'loss': 1.2413, 'grad_norm': 0.93359375, 'learning_rate': 0.00023423987918982803, 'epoch': 0.24}
# {'loss': 1.2226, 'grad_norm': 1.09375, 'learning_rate': 0.00023423142698563405, 'epoch': 0.24}
# {'loss': 1.1282, 'grad_norm': 0.93359375, 'learning_rate': 0.00023422297478144008, 'epoch': 0.24}
# {'loss': 1.3293, 'grad_norm': 0.73828125, 'learning_rate': 0.00023421452257724607, 'epoch': 0.24}
# {'loss': 1.1398, 'grad_norm': 0.8125, 'learning_rate': 0.0002342060703730521, 'epoch': 0.24}
# {'loss': 1.1159, 'grad_norm': 1.046875, 'learning_rate': 0.00023419761816885812, 'epoch': 0.24}
# {'loss': 1.2735, 'grad_norm': 0.875, 'learning_rate': 0.00023418916596466415, 'epoch': 0.24}
# {'loss': 1.0604, 'grad_norm': 1.1875, 'learning_rate': 0.00023418071376047017, 'epoch': 0.24}
# {'loss': 1.1766, 'grad_norm': 0.703125, 'learning_rate': 0.00023417226155627614, 'epoch': 0.24}
# {'loss': 1.1459, 'grad_norm': 0.75390625, 'learning_rate': 0.00023416380935208217, 'epoch': 0.24}
# {'loss': 1.1102, 'grad_norm': 0.75390625, 'learning_rate': 0.0002341553571478882, 'epoch': 0.24}
# {'loss': 1.2591, 'grad_norm': 0.9765625, 'learning_rate': 0.00023414690494369422, 'epoch': 0.24}
# {'loss': 1.0375, 'grad_norm': 0.388671875, 'learning_rate': 0.00023413845273950021, 'epoch': 0.24}
# {'loss': 1.2961, 'grad_norm': 1.203125, 'learning_rate': 0.00023413000053530624, 'epoch': 0.24}
# {'loss': 1.2826, 'grad_norm': 0.79296875, 'learning_rate': 0.00023412154833111226, 'epoch': 0.24}
# {'loss': 1.0794, 'grad_norm': 1.1953125, 'learning_rate': 0.0002341130961269183, 'epoch': 0.24}
# {'loss': 1.1072, 'grad_norm': 0.80078125, 'learning_rate': 0.00023410464392272428, 'epoch': 0.24}
# {'loss': 1.1479, 'grad_norm': 1.0546875, 'learning_rate': 0.0002340961917185303, 'epoch': 0.24}
# {'loss': 1.2743, 'grad_norm': 1.5703125, 'learning_rate': 0.00023408773951433633, 'epoch': 0.24}
# {'loss': 1.1503, 'grad_norm': 0.859375, 'learning_rate': 0.00023407928731014236, 'epoch': 0.24}
# {'loss': 1.2092, 'grad_norm': 1.7265625, 'learning_rate': 0.00023407083510594838, 'epoch': 0.24}
# {'loss': 1.2712, 'grad_norm': 0.9296875, 'learning_rate': 0.00023406238290175435, 'epoch': 0.24}
# {'loss': 0.9964, 'grad_norm': 1.2734375, 'learning_rate': 0.00023405393069756038, 'epoch': 0.24}
# {'loss': 1.2578, 'grad_norm': 1.140625, 'learning_rate': 0.0002340454784933664, 'epoch': 0.24}
# {'loss': 1.1102, 'grad_norm': 0.66015625, 'learning_rate': 0.00023403702628917243, 'epoch': 0.24}
# {'loss': 1.2032, 'grad_norm': 1.2734375, 'learning_rate': 0.00023402857408497842, 'epoch': 0.24}
# {'loss': 1.2184, 'grad_norm': 0.89453125, 'learning_rate': 0.00023402012188078445, 'epoch': 0.24}
# {'loss': 1.1941, 'grad_norm': 0.91015625, 'learning_rate': 0.00023401166967659047, 'epoch': 0.24}
# {'loss': 1.3201, 'grad_norm': 1.0, 'learning_rate': 0.0002340032174723965, 'epoch': 0.24}
# {'loss': 1.0783, 'grad_norm': 0.6796875, 'learning_rate': 0.00023399476526820252, 'epoch': 0.24}
# {'loss': 1.2272, 'grad_norm': 1.2265625, 'learning_rate': 0.00023398631306400852, 'epoch': 0.24}
# {'loss': 1.2035, 'grad_norm': 1.15625, 'learning_rate': 0.00023397786085981454, 'epoch': 0.24}
# {'loss': 1.1441, 'grad_norm': 1.7734375, 'learning_rate': 0.00023396940865562057, 'epoch': 0.24}
# {'loss': 1.1456, 'grad_norm': 1.1796875, 'learning_rate': 0.0002339609564514266, 'epoch': 0.24}
# {'loss': 1.1492, 'grad_norm': 0.890625, 'learning_rate': 0.00023395250424723256, 'epoch': 0.24}
# {'loss': 1.1652, 'grad_norm': 0.8515625, 'learning_rate': 0.0002339440520430386, 'epoch': 0.24}
# {'loss': 1.0868, 'grad_norm': 0.90625, 'learning_rate': 0.0002339355998388446, 'epoch': 0.24}
# {'loss': 1.0976, 'grad_norm': 1.3671875, 'learning_rate': 0.00023392714763465064, 'epoch': 0.24}
# {'loss': 1.2334, 'grad_norm': 1.2734375, 'learning_rate': 0.00023391869543045663, 'epoch': 0.24}
# {'loss': 1.1377, 'grad_norm': 0.85546875, 'learning_rate': 0.00023391024322626266, 'epoch': 0.24}
# {'loss': 1.1194, 'grad_norm': 1.1328125, 'learning_rate': 0.00023390179102206868, 'epoch': 0.24}
# {'loss': 1.1049, 'grad_norm': 0.9296875, 'learning_rate': 0.0002338933388178747, 'epoch': 0.24}
# {'loss': 1.0878, 'grad_norm': 1.3046875, 'learning_rate': 0.00023388488661368073, 'epoch': 0.24}
# {'loss': 1.29, 'grad_norm': 0.87890625, 'learning_rate': 0.00023387643440948673, 'epoch': 0.24}
# {'loss': 1.1317, 'grad_norm': 0.86328125, 'learning_rate': 0.00023386798220529275, 'epoch': 0.24}
# {'loss': 1.1732, 'grad_norm': 0.95703125, 'learning_rate': 0.00023385953000109878, 'epoch': 0.24}
# {'loss': 1.2501, 'grad_norm': 0.6796875, 'learning_rate': 0.0002338510777969048, 'epoch': 0.24}
# {'loss': 1.1358, 'grad_norm': 1.0703125, 'learning_rate': 0.00023384262559271077, 'epoch': 0.24}
# {'loss': 1.4427, 'grad_norm': 0.875, 'learning_rate': 0.0002338341733885168, 'epoch': 0.24}
# {'loss': 1.0967, 'grad_norm': 0.7890625, 'learning_rate': 0.00023382572118432282, 'epoch': 0.24}
# {'loss': 1.2036, 'grad_norm': 1.234375, 'learning_rate': 0.00023381726898012885, 'epoch': 0.24}
# {'loss': 1.299, 'grad_norm': 0.796875, 'learning_rate': 0.00023380881677593485, 'epoch': 0.24}
# {'loss': 1.0579, 'grad_norm': 1.6796875, 'learning_rate': 0.00023380036457174087, 'epoch': 0.24}
# {'loss': 1.2978, 'grad_norm': 1.125, 'learning_rate': 0.0002337919123675469, 'epoch': 0.24}
# {'loss': 1.0654, 'grad_norm': 0.8515625, 'learning_rate': 0.00023378346016335292, 'epoch': 0.24}
# {'loss': 1.2037, 'grad_norm': 1.2109375, 'learning_rate': 0.00023377500795915894, 'epoch': 0.24}
# {'loss': 1.1685, 'grad_norm': 0.8125, 'learning_rate': 0.00023376655575496494, 'epoch': 0.24}
# {'loss': 1.1112, 'grad_norm': 0.56640625, 'learning_rate': 0.00023375810355077097, 'epoch': 0.24}
# {'loss': 1.247, 'grad_norm': 0.80078125, 'learning_rate': 0.000233749651346577, 'epoch': 0.24}
# {'loss': 1.2348, 'grad_norm': 0.67578125, 'learning_rate': 0.00023374119914238301, 'epoch': 0.24}
# {'loss': 1.2547, 'grad_norm': 0.984375, 'learning_rate': 0.00023373274693818898, 'epoch': 0.24}
# {'loss': 1.2812, 'grad_norm': 0.8984375, 'learning_rate': 0.000233724294733995, 'epoch': 0.24}
# {'loss': 1.099, 'grad_norm': 1.546875, 'learning_rate': 0.00023371584252980103, 'epoch': 0.24}
# {'loss': 1.241, 'grad_norm': 0.828125, 'learning_rate': 0.00023370739032560706, 'epoch': 0.24}
# {'loss': 1.1893, 'grad_norm': 1.0859375, 'learning_rate': 0.00023369893812141306, 'epoch': 0.24}
# {'loss': 1.1539, 'grad_norm': 1.03125, 'learning_rate': 0.00023369048591721908, 'epoch': 0.24}
# {'loss': 1.209, 'grad_norm': 1.09375, 'learning_rate': 0.0002336820337130251, 'epoch': 0.24}
# {'loss': 1.0555, 'grad_norm': 0.890625, 'learning_rate': 0.00023367358150883113, 'epoch': 0.24}
# {'loss': 1.2223, 'grad_norm': 0.91015625, 'learning_rate': 0.00023366512930463715, 'epoch': 0.24}
# {'loss': 1.1145, 'grad_norm': 0.77734375, 'learning_rate': 0.00023365667710044315, 'epoch': 0.24}
# {'loss': 1.1287, 'grad_norm': 2.453125, 'learning_rate': 0.00023364822489624918, 'epoch': 0.24}
# {'loss': 1.123, 'grad_norm': 0.5625, 'learning_rate': 0.0002336397726920552, 'epoch': 0.24}
# {'loss': 1.1817, 'grad_norm': 1.390625, 'learning_rate': 0.00023363132048786122, 'epoch': 0.24}
# {'loss': 1.1901, 'grad_norm': 1.0078125, 'learning_rate': 0.0002336228682836672, 'epoch': 0.24}
# {'loss': 1.0744, 'grad_norm': 0.6796875, 'learning_rate': 0.00023361441607947322, 'epoch': 0.24}
# {'loss': 1.0686, 'grad_norm': 1.3203125, 'learning_rate': 0.00023360596387527924, 'epoch': 0.24}
# {'loss': 1.2288, 'grad_norm': 0.76953125, 'learning_rate': 0.00023359751167108527, 'epoch': 0.24}
# {'loss': 1.0949, 'grad_norm': 1.1796875, 'learning_rate': 0.00023358905946689127, 'epoch': 0.24}
# {'loss': 1.261, 'grad_norm': 0.97265625, 'learning_rate': 0.0002335806072626973, 'epoch': 0.24}
# {'loss': 1.1967, 'grad_norm': 0.87109375, 'learning_rate': 0.00023357215505850332, 'epoch': 0.24}
# {'loss': 1.1871, 'grad_norm': 1.3359375, 'learning_rate': 0.00023356370285430934, 'epoch': 0.24}
# {'loss': 1.2192, 'grad_norm': 1.0390625, 'learning_rate': 0.00023355525065011536, 'epoch': 0.24}
# {'loss': 1.1754, 'grad_norm': 0.984375, 'learning_rate': 0.00023354679844592136, 'epoch': 0.24}
# {'loss': 1.2397, 'grad_norm': 0.87109375, 'learning_rate': 0.00023353834624172739, 'epoch': 0.24}
# {'loss': 1.155, 'grad_norm': 0.87109375, 'learning_rate': 0.0002335298940375334, 'epoch': 0.24}
# {'loss': 1.0968, 'grad_norm': 1.1875, 'learning_rate': 0.00023352144183333944, 'epoch': 0.24}
# {'loss': 1.2487, 'grad_norm': 0.74609375, 'learning_rate': 0.00023351298962914543, 'epoch': 0.24}
# {'loss': 1.0885, 'grad_norm': 1.3203125, 'learning_rate': 0.00023350453742495143, 'epoch': 0.25}
# {'loss': 1.2661, 'grad_norm': 0.6953125, 'learning_rate': 0.00023349608522075745, 'epoch': 0.25}
# {'loss': 1.1823, 'grad_norm': 0.79296875, 'learning_rate': 0.00023348763301656348, 'epoch': 0.25}
# {'loss': 1.206, 'grad_norm': 1.3984375, 'learning_rate': 0.0002334791808123695, 'epoch': 0.25}
# {'loss': 1.1334, 'grad_norm': 0.8125, 'learning_rate': 0.0002334707286081755, 'epoch': 0.25}
# {'loss': 1.1409, 'grad_norm': 1.6171875, 'learning_rate': 0.00023346227640398153, 'epoch': 0.25}
# {'loss': 1.2223, 'grad_norm': 0.78125, 'learning_rate': 0.00023345382419978755, 'epoch': 0.25}
# {'loss': 1.2062, 'grad_norm': 0.78125, 'learning_rate': 0.00023344537199559357, 'epoch': 0.25}
# {'loss': 1.2106, 'grad_norm': 1.7734375, 'learning_rate': 0.00023343691979139957, 'epoch': 0.25}
# {'loss': 1.2085, 'grad_norm': 0.890625, 'learning_rate': 0.0002334284675872056, 'epoch': 0.25}
# {'loss': 1.1675, 'grad_norm': 2.109375, 'learning_rate': 0.00023342001538301162, 'epoch': 0.25}
# {'loss': 1.3174, 'grad_norm': 1.015625, 'learning_rate': 0.00023341156317881765, 'epoch': 0.25}
# {'loss': 1.2906, 'grad_norm': 0.76171875, 'learning_rate': 0.00023340311097462364, 'epoch': 0.25}
# {'loss': 1.2459, 'grad_norm': 1.0078125, 'learning_rate': 0.00023339465877042967, 'epoch': 0.25}
# {'loss': 1.1756, 'grad_norm': 0.9453125, 'learning_rate': 0.00023338620656623567, 'epoch': 0.25}
# {'loss': 1.1453, 'grad_norm': 2.40625, 'learning_rate': 0.0002333777543620417, 'epoch': 0.25}
# {'loss': 1.2028, 'grad_norm': 0.74609375, 'learning_rate': 0.00023336930215784771, 'epoch': 0.25}
# {'loss': 1.1232, 'grad_norm': 0.89453125, 'learning_rate': 0.0002333608499536537, 'epoch': 0.25}
# {'loss': 1.2151, 'grad_norm': 0.921875, 'learning_rate': 0.00023335239774945974, 'epoch': 0.25}
# {'loss': 1.2172, 'grad_norm': 0.953125, 'learning_rate': 0.00023334394554526576, 'epoch': 0.25}
# {'loss': 0.9529, 'grad_norm': 0.48046875, 'learning_rate': 0.00023333549334107179, 'epoch': 0.25}
# {'loss': 1.2689, 'grad_norm': 1.1640625, 'learning_rate': 0.00023332704113687778, 'epoch': 0.25}
# {'loss': 1.0426, 'grad_norm': 0.59375, 'learning_rate': 0.0002333185889326838, 'epoch': 0.25}
# {'loss': 1.2474, 'grad_norm': 1.15625, 'learning_rate': 0.00023331013672848983, 'epoch': 0.25}
# {'loss': 1.203, 'grad_norm': 0.9453125, 'learning_rate': 0.00023330168452429586, 'epoch': 0.25}
# {'loss': 1.0798, 'grad_norm': 0.462890625, 'learning_rate': 0.00023329323232010185, 'epoch': 0.25}
# {'loss': 1.2498, 'grad_norm': 1.1015625, 'learning_rate': 0.00023328478011590788, 'epoch': 0.25}
# {'loss': 1.1923, 'grad_norm': 0.81640625, 'learning_rate': 0.0002332763279117139, 'epoch': 0.25}
# {'loss': 1.0797, 'grad_norm': 1.359375, 'learning_rate': 0.0002332678757075199, 'epoch': 0.25}
# {'loss': 1.1419, 'grad_norm': 0.9375, 'learning_rate': 0.00023325942350332592, 'epoch': 0.25}
# {'loss': 1.1151, 'grad_norm': 0.9609375, 'learning_rate': 0.00023325097129913192, 'epoch': 0.25}
# {'loss': 1.175, 'grad_norm': 0.93359375, 'learning_rate': 0.00023324251909493795, 'epoch': 0.25}
# {'loss': 1.1598, 'grad_norm': 1.015625, 'learning_rate': 0.00023323406689074397, 'epoch': 0.25}
# {'loss': 1.1533, 'grad_norm': 0.95703125, 'learning_rate': 0.00023322561468655, 'epoch': 0.25}
# {'loss': 1.268, 'grad_norm': 0.75390625, 'learning_rate': 0.000233217162482356, 'epoch': 0.25}
# {'loss': 1.1733, 'grad_norm': 1.4140625, 'learning_rate': 0.00023320871027816202, 'epoch': 0.25}
# {'loss': 1.3389, 'grad_norm': 1.2421875, 'learning_rate': 0.00023320025807396804, 'epoch': 0.25}
# {'loss': 1.1792, 'grad_norm': 0.796875, 'learning_rate': 0.00023319180586977407, 'epoch': 0.25}
# {'loss': 1.1778, 'grad_norm': 1.609375, 'learning_rate': 0.00023318335366558006, 'epoch': 0.25}
# {'loss': 1.2767, 'grad_norm': 1.0703125, 'learning_rate': 0.0002331749014613861, 'epoch': 0.25}
# {'loss': 1.0904, 'grad_norm': 1.2578125, 'learning_rate': 0.0002331664492571921, 'epoch': 0.25}
# {'loss': 1.2602, 'grad_norm': 0.9375, 'learning_rate': 0.00023315799705299814, 'epoch': 0.25}
# {'loss': 1.2266, 'grad_norm': 0.80078125, 'learning_rate': 0.00023314954484880414, 'epoch': 0.25}
# {'loss': 1.1787, 'grad_norm': 0.984375, 'learning_rate': 0.00023314109264461013, 'epoch': 0.25}
# {'loss': 1.3373, 'grad_norm': 0.75, 'learning_rate': 0.00023313264044041616, 'epoch': 0.25}
# {'loss': 1.0819, 'grad_norm': 2.125, 'learning_rate': 0.00023312418823622218, 'epoch': 0.25}
# {'loss': 1.1983, 'grad_norm': 0.92578125, 'learning_rate': 0.0002331157360320282, 'epoch': 0.25}
# {'loss': 1.1296, 'grad_norm': 0.796875, 'learning_rate': 0.0002331072838278342, 'epoch': 0.25}
# {'loss': 1.1682, 'grad_norm': 1.3359375, 'learning_rate': 0.00023309883162364023, 'epoch': 0.25}
# {'loss': 1.2198, 'grad_norm': 0.84375, 'learning_rate': 0.00023309037941944625, 'epoch': 0.25}
# {'loss': 1.0944, 'grad_norm': 0.640625, 'learning_rate': 0.00023308192721525228, 'epoch': 0.25}
# {'loss': 1.238, 'grad_norm': 1.0703125, 'learning_rate': 0.00023307347501105827, 'epoch': 0.25}
# {'loss': 1.1305, 'grad_norm': 0.8515625, 'learning_rate': 0.0002330650228068643, 'epoch': 0.25}
# {'loss': 1.1548, 'grad_norm': 0.98046875, 'learning_rate': 0.00023305657060267032, 'epoch': 0.25}
# {'loss': 1.0991, 'grad_norm': 0.81640625, 'learning_rate': 0.00023304811839847635, 'epoch': 0.25}
# {'loss': 1.129, 'grad_norm': 1.4453125, 'learning_rate': 0.00023303966619428237, 'epoch': 0.25}
# {'loss': 1.2036, 'grad_norm': 0.98828125, 'learning_rate': 0.00023303121399008834, 'epoch': 0.25}
# {'loss': 1.1212, 'grad_norm': 0.67578125, 'learning_rate': 0.00023302276178589437, 'epoch': 0.25}
# {'loss': 1.079, 'grad_norm': 0.9140625, 'learning_rate': 0.0002330143095817004, 'epoch': 0.25}
# {'loss': 1.3768, 'grad_norm': 0.9375, 'learning_rate': 0.00023300585737750642, 'epoch': 0.25}
# {'loss': 1.0961, 'grad_norm': 1.6484375, 'learning_rate': 0.00023299740517331241, 'epoch': 0.25}
# {'loss': 1.1905, 'grad_norm': 1.078125, 'learning_rate': 0.00023298895296911844, 'epoch': 0.25}
# {'loss': 1.1745, 'grad_norm': 1.2734375, 'learning_rate': 0.00023298050076492446, 'epoch': 0.25}
# {'loss': 1.1502, 'grad_norm': 1.0859375, 'learning_rate': 0.0002329720485607305, 'epoch': 0.25}
# {'loss': 1.104, 'grad_norm': 0.96875, 'learning_rate': 0.0002329635963565365, 'epoch': 0.25}
# {'loss': 1.086, 'grad_norm': 0.8828125, 'learning_rate': 0.0002329551441523425, 'epoch': 0.25}
# {'loss': 1.198, 'grad_norm': 0.984375, 'learning_rate': 0.00023294669194814853, 'epoch': 0.25}
# {'loss': 1.1438, 'grad_norm': 0.7890625, 'learning_rate': 0.00023293823974395456, 'epoch': 0.25}
# ...
# {'loss': 1.0326, 'grad_norm': 0.8046875, 'learning_rate': 1.3901058497705226e-06, 'epoch': 1.0}
# {'loss': 1.0187, 'grad_norm': 1.46875, 'learning_rate': 1.3816536455765388e-06, 'epoch': 1.0}
# {'loss': 1.1924, 'grad_norm': 1.0078125, 'learning_rate': 1.373201441382555e-06, 'epoch': 1.0}
# {'loss': 0.9303, 'grad_norm': 1.8046875, 'learning_rate': 1.3647492371885712e-06, 'epoch': 1.0}
# {'loss': 1.3236, 'grad_norm': 1.453125, 'learning_rate': 1.3562970329945876e-06, 'epoch': 1.0}
# {'loss': 1.1167, 'grad_norm': 0.83984375, 'learning_rate': 1.3478448288006041e-06, 'epoch': 1.0}
# {'loss': 1.2333, 'grad_norm': 1.15625, 'learning_rate': 1.3393926246066202e-06, 'epoch': 1.0}
# {'loss': 1.1372, 'grad_norm': 0.8125, 'learning_rate': 1.3309404204126365e-06, 'epoch': 1.0}
# {'loss': 0.9885, 'grad_norm': 0.90625, 'learning_rate': 1.322488216218653e-06, 'epoch': 1.0}
# {'loss': 1.1961, 'grad_norm': 1.09375, 'learning_rate': 1.314036012024669e-06, 'epoch': 1.0}
# {'loss': 1.1132, 'grad_norm': 0.83203125, 'learning_rate': 1.3055838078306855e-06, 'epoch': 1.0}
# {'loss': 1.1321, 'grad_norm': 1.40625, 'learning_rate': 1.2971316036367016e-06, 'epoch': 1.0}
# {'loss': 1.0584, 'grad_norm': 0.8046875, 'learning_rate': 1.2886793994427178e-06, 'epoch': 1.0}
# {'loss': 1.0645, 'grad_norm': 1.5703125, 'learning_rate': 1.2802271952487343e-06, 'epoch': 1.0}
# {'loss': 1.1279, 'grad_norm': 0.81640625, 'learning_rate': 1.2717749910547504e-06, 'epoch': 1.0}
# {'loss': 1.0791, 'grad_norm': 0.7109375, 'learning_rate': 1.2633227868607669e-06, 'epoch': 1.0}
# {'loss': 1.104, 'grad_norm': 1.5078125, 'learning_rate': 1.254870582666783e-06, 'epoch': 1.0}
# {'loss': 1.0336, 'grad_norm': 1.03125, 'learning_rate': 1.2464183784727992e-06, 'epoch': 1.0}
# {'loss': 0.9496, 'grad_norm': 0.875, 'learning_rate': 1.2379661742788157e-06, 'epoch': 1.0}
# {'loss': 1.1806, 'grad_norm': 1.0234375, 'learning_rate': 1.2295139700848317e-06, 'epoch': 1.0}
# {'loss': 1.0482, 'grad_norm': 1.0, 'learning_rate': 1.2210617658908482e-06, 'epoch': 1.0}
# {'loss': 1.1111, 'grad_norm': 1.265625, 'learning_rate': 1.2126095616968645e-06, 'epoch': 1.0}
# {'loss': 1.1064, 'grad_norm': 0.8046875, 'learning_rate': 1.2041573575028805e-06, 'epoch': 1.0}
# {'loss': 1.0265, 'grad_norm': 1.25, 'learning_rate': 1.195705153308897e-06, 'epoch': 1.0}
# {'loss': 1.2173, 'grad_norm': 0.88671875, 'learning_rate': 1.187252949114913e-06, 'epoch': 1.0}
# {'loss': 1.0527, 'grad_norm': 0.83203125, 'learning_rate': 1.1788007449209296e-06, 'epoch': 1.0}
# {'loss': 1.1857, 'grad_norm': 1.25, 'learning_rate': 1.1703485407269458e-06, 'epoch': 1.0}
# {'loss': 1.093, 'grad_norm': 0.8046875, 'learning_rate': 1.1618963365329621e-06, 'epoch': 1.0}
# {'loss': 0.9532, 'grad_norm': 1.0390625, 'learning_rate': 1.1534441323389784e-06, 'epoch': 1.0}
# {'loss': 1.2521, 'grad_norm': 1.2890625, 'learning_rate': 1.1449919281449947e-06, 'epoch': 1.0}
# {'loss': 1.0388, 'grad_norm': 0.95703125, 'learning_rate': 1.136539723951011e-06, 'epoch': 1.0}
# {'loss': 1.0759, 'grad_norm': 1.171875, 'learning_rate': 1.1280875197570272e-06, 'epoch': 1.0}
# {'loss': 1.1707, 'grad_norm': 1.3515625, 'learning_rate': 1.1196353155630435e-06, 'epoch': 1.0}
# {'loss': 1.0476, 'grad_norm': 1.8203125, 'learning_rate': 1.1111831113690598e-06, 'epoch': 1.0}
# {'loss': 1.1501, 'grad_norm': 0.953125, 'learning_rate': 1.102730907175076e-06, 'epoch': 1.0}
# {'loss': 1.1086, 'grad_norm': 0.99609375, 'learning_rate': 1.0942787029810923e-06, 'epoch': 1.0}
# {'loss': 1.0446, 'grad_norm': 2.84375, 'learning_rate': 1.0858264987871086e-06, 'epoch': 1.0}
# {'loss': 1.0593, 'grad_norm': 0.98828125, 'learning_rate': 1.0773742945931248e-06, 'epoch': 1.0}
# {'loss': 1.0692, 'grad_norm': 1.046875, 'learning_rate': 1.0689220903991411e-06, 'epoch': 1.0}
# {'loss': 1.1506, 'grad_norm': 0.8046875, 'learning_rate': 1.0604698862051574e-06, 'epoch': 1.0}
# {'loss': 1.086, 'grad_norm': 0.76171875, 'learning_rate': 1.0520176820111737e-06, 'epoch': 1.0}
# {'loss': 1.0455, 'grad_norm': 1.09375, 'learning_rate': 1.04356547781719e-06, 'epoch': 1.0}
# {'loss': 1.0634, 'grad_norm': 0.67578125, 'learning_rate': 1.0351132736232062e-06, 'epoch': 1.0}
# {'loss': 1.0325, 'grad_norm': 0.8984375, 'learning_rate': 1.0266610694292225e-06, 'epoch': 1.0}
# {'loss': 1.1468, 'grad_norm': 0.98828125, 'learning_rate': 1.018208865235239e-06, 'epoch': 1.0}
# {'loss': 1.0789, 'grad_norm': 0.85546875, 'learning_rate': 1.009756661041255e-06, 'epoch': 1.0}
# {'loss': 1.1413, 'grad_norm': 1.3046875, 'learning_rate': 1.0013044568472713e-06, 'epoch': 1.0}
# {'loss': 1.1353, 'grad_norm': 1.15625, 'learning_rate': 9.928522526532876e-07, 'epoch': 1.0}
# {'loss': 1.0746, 'grad_norm': 1.546875, 'learning_rate': 9.84400048459304e-07, 'epoch': 1.0}
# {'loss': 1.1347, 'grad_norm': 1.7265625, 'learning_rate': 9.759478442653203e-07, 'epoch': 1.0}
# {'loss': 1.0005, 'grad_norm': 0.74609375, 'learning_rate': 9.674956400713366e-07, 'epoch': 1.0}
# {'loss': 1.1922, 'grad_norm': 1.2421875, 'learning_rate': 9.590434358773527e-07, 'epoch': 1.0}
# {'loss': 1.161, 'grad_norm': 0.90625, 'learning_rate': 9.505912316833691e-07, 'epoch': 1.0}
# {'loss': 0.9354, 'grad_norm': 1.140625, 'learning_rate': 9.421390274893854e-07, 'epoch': 1.0}
# {'loss': 1.207, 'grad_norm': 1.0625, 'learning_rate': 9.336868232954016e-07, 'epoch': 1.0}
# {'loss': 1.2094, 'grad_norm': 0.7578125, 'learning_rate': 9.252346191014179e-07, 'epoch': 1.0}
# {'loss': 1.1814, 'grad_norm': 1.4140625, 'learning_rate': 9.167824149074342e-07, 'epoch': 1.0}
# {'loss': 1.2068, 'grad_norm': 0.83984375, 'learning_rate': 9.083302107134505e-07, 'epoch': 1.0}
# {'loss': 1.027, 'grad_norm': 1.234375, 'learning_rate': 8.998780065194668e-07, 'epoch': 1.0}
# {'loss': 1.0808, 'grad_norm': 1.2109375, 'learning_rate': 8.91425802325483e-07, 'epoch': 1.0}
# {'loss': 1.0649, 'grad_norm': 0.84375, 'learning_rate': 8.829735981314994e-07, 'epoch': 1.0}
# {'loss': 1.1177, 'grad_norm': 1.1328125, 'learning_rate': 8.745213939375156e-07, 'epoch': 1.0}
# {'loss': 1.2464, 'grad_norm': 0.9921875, 'learning_rate': 8.660691897435319e-07, 'epoch': 1.0}
# {'loss': 1.0331, 'grad_norm': 1.2734375, 'learning_rate': 8.576169855495481e-07, 'epoch': 1.0}
# {'loss': 1.086, 'grad_norm': 1.078125, 'learning_rate': 8.491647813555644e-07, 'epoch': 1.0}
# {'loss': 1.1658, 'grad_norm': 0.95703125, 'learning_rate': 8.407125771615808e-07, 'epoch': 1.0}
# {'loss': 0.9742, 'grad_norm': 0.88671875, 'learning_rate': 8.32260372967597e-07, 'epoch': 1.0}
# {'loss': 1.1326, 'grad_norm': 0.9375, 'learning_rate': 8.238081687736132e-07, 'epoch': 1.0}
# {'loss': 1.0053, 'grad_norm': 1.3125, 'learning_rate': 8.153559645796295e-07, 'epoch': 1.0}
# {'loss': 1.2248, 'grad_norm': 1.375, 'learning_rate': 8.069037603856459e-07, 'epoch': 1.0}
# {'loss': 1.0888, 'grad_norm': 0.98046875, 'learning_rate': 7.984515561916622e-07, 'epoch': 1.0}
# {'loss': 0.9937, 'grad_norm': 1.34375, 'learning_rate': 7.899993519976783e-07, 'epoch': 1.0}
# {'loss': 1.1225, 'grad_norm': 0.76953125, 'learning_rate': 7.815471478036946e-07, 'epoch': 1.0}
# {'loss': 1.0154, 'grad_norm': 1.84375, 'learning_rate': 7.73094943609711e-07, 'epoch': 1.0}
# {'loss': 1.133, 'grad_norm': 0.9765625, 'learning_rate': 7.646427394157272e-07, 'epoch': 1.0}
# {'loss': 1.0339, 'grad_norm': 0.9140625, 'learning_rate': 7.561905352217435e-07, 'epoch': 1.0}
# {'loss': 0.9649, 'grad_norm': 1.265625, 'learning_rate': 7.477383310277598e-07, 'epoch': 1.0}
# {'loss': 1.058, 'grad_norm': 0.72265625, 'learning_rate': 7.392861268337762e-07, 'epoch': 1.0}
# {'loss': 0.9361, 'grad_norm': 0.91015625, 'learning_rate': 7.308339226397923e-07, 'epoch': 1.0}
# {'loss': 1.1791, 'grad_norm': 0.9765625, 'learning_rate': 7.223817184458086e-07, 'epoch': 1.0}
# {'loss': 1.1178, 'grad_norm': 1.2109375, 'learning_rate': 7.139295142518249e-07, 'epoch': 1.0}
# {'loss': 1.2417, 'grad_norm': 1.109375, 'learning_rate': 7.054773100578413e-07, 'epoch': 1.0}
# {'loss': 1.1569, 'grad_norm': 1.0859375, 'learning_rate': 6.970251058638575e-07, 'epoch': 1.0}
# {'loss': 1.0736, 'grad_norm': 1.5546875, 'learning_rate': 6.885729016698737e-07, 'epoch': 1.0}
# {'loss': 1.149, 'grad_norm': 0.9296875, 'learning_rate': 6.8012069747589e-07, 'epoch': 1.0}
# {'loss': 1.1332, 'grad_norm': 0.8828125, 'learning_rate': 6.716684932819063e-07, 'epoch': 1.0}
# {'loss': 1.0553, 'grad_norm': 1.4375, 'learning_rate': 6.632162890879226e-07, 'epoch': 1.0}
# {'loss': 1.2301, 'grad_norm': 1.0, 'learning_rate': 6.547640848939389e-07, 'epoch': 1.0}
# {'loss': 0.9876, 'grad_norm': 2.09375, 'learning_rate': 6.463118806999552e-07, 'epoch': 1.0}
# {'loss': 1.1697, 'grad_norm': 0.96484375, 'learning_rate': 6.378596765059713e-07, 'epoch': 1.0}
# {'loss': 1.0448, 'grad_norm': 0.8203125, 'learning_rate': 6.294074723119877e-07, 'epoch': 1.0}
# {'loss': 1.1044, 'grad_norm': 1.21875, 'learning_rate': 6.20955268118004e-07, 'epoch': 1.0}
# {'loss': 1.0983, 'grad_norm': 1.1171875, 'learning_rate': 6.125030639240203e-07, 'epoch': 1.0}
# {'loss': 1.126, 'grad_norm': 1.796875, 'learning_rate': 6.040508597300365e-07, 'epoch': 1.0}
# {'loss': 1.204, 'grad_norm': 1.109375, 'learning_rate': 5.955986555360529e-07, 'epoch': 1.0}
# {'loss': 0.9183, 'grad_norm': 0.890625, 'learning_rate': 5.871464513420691e-07, 'epoch': 1.0}
# {'loss': 1.0928, 'grad_norm': 1.0625, 'learning_rate': 5.786942471480853e-07, 'epoch': 1.0}
# {'loss': 1.1548, 'grad_norm': 1.0625, 'learning_rate': 5.702420429541017e-07, 'epoch': 1.0}
# {'loss': 1.0423, 'grad_norm': 1.25, 'learning_rate': 5.617898387601179e-07, 'epoch': 1.0}
# {'loss': 1.087, 'grad_norm': 0.88671875, 'learning_rate': 5.533376345661343e-07, 'epoch': 1.0}
# {'loss': 1.0764, 'grad_norm': 0.91015625, 'learning_rate': 5.448854303721505e-07, 'epoch': 1.0}
# {'loss': 1.0304, 'grad_norm': 1.4453125, 'learning_rate': 5.364332261781668e-07, 'epoch': 1.0}
# {'loss': 1.1424, 'grad_norm': 0.78515625, 'learning_rate': 5.279810219841831e-07, 'epoch': 1.0}
# {'loss': 0.9683, 'grad_norm': 0.91015625, 'learning_rate': 5.195288177901994e-07, 'epoch': 1.0}
# {'loss': 1.1506, 'grad_norm': 1.7109375, 'learning_rate': 5.110766135962156e-07, 'epoch': 1.0}
# {'loss': 1.1288, 'grad_norm': 0.8125, 'learning_rate': 5.026244094022319e-07, 'epoch': 1.0}
# {'loss': 1.1339, 'grad_norm': 1.71875, 'learning_rate': 4.941722052082482e-07, 'epoch': 1.0}
# {'loss': 1.1473, 'grad_norm': 0.91015625, 'learning_rate': 4.857200010142644e-07, 'epoch': 1.0}
# {'loss': 1.0265, 'grad_norm': 1.875, 'learning_rate': 4.772677968202807e-07, 'epoch': 1.0}
# {'loss': 1.1651, 'grad_norm': 0.87109375, 'learning_rate': 4.6881559262629704e-07, 'epoch': 1.0}
# {'loss': 1.1426, 'grad_norm': 0.65234375, 'learning_rate': 4.603633884323133e-07, 'epoch': 1.0}
# {'loss': 1.1166, 'grad_norm': 1.265625, 'learning_rate': 4.519111842383296e-07, 'epoch': 1.0}
# {'loss': 1.0556, 'grad_norm': 0.9375, 'learning_rate': 4.4345898004434586e-07, 'epoch': 1.0}
# {'loss': 1.1101, 'grad_norm': 0.93359375, 'learning_rate': 4.350067758503621e-07, 'epoch': 1.0}
# {'loss': 1.1575, 'grad_norm': 1.03125, 'learning_rate': 4.265545716563784e-07, 'epoch': 1.0}
# {'loss': 1.0619, 'grad_norm': 0.8671875, 'learning_rate': 4.181023674623947e-07, 'epoch': 1.0}
# {'loss': 1.0619, 'grad_norm': 1.1015625, 'learning_rate': 4.09650163268411e-07, 'epoch': 1.0}
# {'loss': 1.0957, 'grad_norm': 0.859375, 'learning_rate': 4.011979590744272e-07, 'epoch': 1.0}
# {'loss': 1.0344, 'grad_norm': 1.3828125, 'learning_rate': 3.9274575488044355e-07, 'epoch': 1.0}
# {'loss': 1.2568, 'grad_norm': 0.91796875, 'learning_rate': 3.8429355068645977e-07, 'epoch': 1.0}
# {'loss': 1.1228, 'grad_norm': 0.8046875, 'learning_rate': 3.758413464924761e-07, 'epoch': 1.0}
# {'loss': 1.0379, 'grad_norm': 1.7578125, 'learning_rate': 3.6738914229849237e-07, 'epoch': 1.0}
# {'loss': 1.2004, 'grad_norm': 1.4453125, 'learning_rate': 3.589369381045087e-07, 'epoch': 1.0}
# {'loss': 1.0458, 'grad_norm': 1.421875, 'learning_rate': 3.504847339105249e-07, 'epoch': 1.0}
# {'loss': 1.1078, 'grad_norm': 0.98046875, 'learning_rate': 3.4203252971654124e-07, 'epoch': 1.0}
# {'loss': 1.1122, 'grad_norm': 0.8984375, 'learning_rate': 3.3358032552255746e-07, 'epoch': 1.0}
# {'loss': 1.1405, 'grad_norm': 1.0390625, 'learning_rate': 3.251281213285738e-07, 'epoch': 1.0}
# {'loss': 1.1783, 'grad_norm': 0.8984375, 'learning_rate': 3.1667591713459005e-07, 'epoch': 1.0}
# {'loss': 1.0902, 'grad_norm': 1.1796875, 'learning_rate': 3.082237129406064e-07, 'epoch': 1.0}
# {'loss': 1.1811, 'grad_norm': 1.0546875, 'learning_rate': 2.997715087466226e-07, 'epoch': 1.0}
# {'loss': 1.0809, 'grad_norm': 0.81640625, 'learning_rate': 2.9131930455263887e-07, 'epoch': 1.0}
# {'loss': 1.1108, 'grad_norm': 1.296875, 'learning_rate': 2.8286710035865514e-07, 'epoch': 1.0}
# {'loss': 1.1077, 'grad_norm': 1.6953125, 'learning_rate': 2.7441489616467147e-07, 'epoch': 1.0}
# {'loss': 0.9282, 'grad_norm': 0.796875, 'learning_rate': 2.6596269197068774e-07, 'epoch': 1.0}
# {'loss': 1.125, 'grad_norm': 1.0234375, 'learning_rate': 2.57510487776704e-07, 'epoch': 1.0}
# {'loss': 1.0334, 'grad_norm': 0.63671875, 'learning_rate': 2.490582835827203e-07, 'epoch': 1.0}
# {'loss': 1.0581, 'grad_norm': 1.140625, 'learning_rate': 2.4060607938873656e-07, 'epoch': 1.0}
# {'loss': 1.0424, 'grad_norm': 0.94140625, 'learning_rate': 2.3215387519475286e-07, 'epoch': 1.0}
# {'loss': 0.9966, 'grad_norm': 1.0703125, 'learning_rate': 2.2370167100076913e-07, 'epoch': 1.0}
# {'loss': 1.151, 'grad_norm': 0.77734375, 'learning_rate': 2.152494668067854e-07, 'epoch': 1.0}
# {'loss': 0.9344, 'grad_norm': 0.703125, 'learning_rate': 2.067972626128017e-07, 'epoch': 1.0}
# {'loss': 1.0026, 'grad_norm': 1.2890625, 'learning_rate': 1.9834505841881797e-07, 'epoch': 1.0}
# {'loss': 1.186, 'grad_norm': 1.1015625, 'learning_rate': 1.8989285422483425e-07, 'epoch': 1.0}
# {'loss': 1.063, 'grad_norm': 1.5, 'learning_rate': 1.8144065003085055e-07, 'epoch': 1.0}
# {'loss': 1.1489, 'grad_norm': 0.82421875, 'learning_rate': 1.7298844583686682e-07, 'epoch': 1.0}
# {'loss': 0.9712, 'grad_norm': 0.98046875, 'learning_rate': 1.645362416428831e-07, 'epoch': 1.0}
# {'loss': 1.1329, 'grad_norm': 1.171875, 'learning_rate': 1.560840374488994e-07, 'epoch': 1.0}
# {'loss': 1.1336, 'grad_norm': 0.76953125, 'learning_rate': 1.4763183325491566e-07, 'epoch': 1.0}
# {'loss': 0.9907, 'grad_norm': 1.5, 'learning_rate': 1.3917962906093193e-07, 'epoch': 1.0}
# {'loss': 1.241, 'grad_norm': 0.95703125, 'learning_rate': 1.307274248669482e-07, 'epoch': 1.0}
# {'loss': 1.0662, 'grad_norm': 0.8125, 'learning_rate': 1.2227522067296448e-07, 'epoch': 1.0}
# {'loss': 1.0496, 'grad_norm': 0.8984375, 'learning_rate': 1.1382301647898076e-07, 'epoch': 1.0}
# {'loss': 1.1982, 'grad_norm': 0.92578125, 'learning_rate': 1.0537081228499705e-07, 'epoch': 1.0}
# {'loss': 1.0695, 'grad_norm': 2.09375, 'learning_rate': 9.691860809101334e-08, 'epoch': 1.0}
# {'loss': 1.0561, 'grad_norm': 0.9765625, 'learning_rate': 8.846640389702961e-08, 'epoch': 1.0}
# {'loss': 1.0735, 'grad_norm': 0.91015625, 'learning_rate': 8.00141997030459e-08, 'epoch': 1.0}
# {'loss': 1.1691, 'grad_norm': 1.1796875, 'learning_rate': 7.156199550906217e-08, 'epoch': 1.0}
# {'loss': 1.079, 'grad_norm': 0.921875, 'learning_rate': 6.310979131507844e-08, 'epoch': 1.0}
# {'loss': 1.0626, 'grad_norm': 1.1796875, 'learning_rate': 5.4657587121094725e-08, 'epoch': 1.0}
# {'loss': 1.1792, 'grad_norm': 1.0625, 'learning_rate': 4.620538292711101e-08, 'epoch': 1.0}
# {'loss': 1.1527, 'grad_norm': 1.0078125, 'learning_rate': 3.775317873312728e-08, 'epoch': 1.0}
# {'loss': 1.1244, 'grad_norm': 1.0234375, 'learning_rate': 2.9300974539143565e-08, 'epoch': 1.0}
# {'loss': 1.1186, 'grad_norm': 0.76171875, 'learning_rate': 2.084877034515984e-08, 'epoch': 1.0}
# {'loss': 1.1255, 'grad_norm': 0.76171875, 'learning_rate': 1.2396566151176123e-08, 'epoch': 1.0}
# {'loss': 1.2232, 'grad_norm': 1.2578125, 'learning_rate': 3.9443619571924024e-09, 'epoch': 1.0}
# {'train_runtime': 702337.3492, 'train_samples_per_second': 3.126, 'train_steps_per_second': 1.563, 'train_loss': 0.8568375437861445, 'epoch': 1.0}
# TrainOutput(global_step=1097744, training_loss=0.8568375437861445, metrics={'train_runtime': 702337.3492, 'train_samples_per_second': 3.126, 'train_steps_per_second': 1.563, 'train_loss': 0.8568375437861445, 'epoch': 1.0})

# %%
trainer.model.save_pretrained(output_dir)
