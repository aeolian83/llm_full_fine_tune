# %%
import pandas as pd

# %%
csv_dir = "/mnt/t7/dnn/llm_practicing/05_RAG_practicing/datas/BUSAN_LOCAL_RESTAURNATS_FILLED.csv"

# %%
bs_re_df = pd.read_csv(csv_dir)

# %%
bs_re_df.head()
# Out:
#   MENU_TYPE RESTAURANT_NAME_KOREAN ADDRESS_KOREAN  \
# 0        한식              해운대 신 대구탕         129.08
# 1       뷔페식                   해암뷔페        129.081
# 2        한식                   할매보쌈         129.08
# 3       중국식                    팔선각        129.075
# 4        일식                   팔미초밥        129.082
#
#                      MENU_NAME NATIONAL_PHONE_NUMBER DISTRICT_NAME LATITUDE  \
# 0   부산광역시 연제구 연산동 1127번지 5호 1층                   대구탕       00:00.0  00:00.0
# 1  부산광역시 연제구 연산동 1242번지 8호 ,13                    뷔페       00:00.0  00:00.0
# 2      부산광역시 연제구 연산동 1242번지 6호                    보쌈       00:00.0  00:00.0
# 3      부산광역시 연제구 거제동 1490번지 2호                    중식       00:00.0  00:00.0
# 4  부산광역시 연제구 연산동 701번지 8호 팔미빌딩                   회초밥       00:00.0  00:00.0
#
#    LONGITUDE    RESTAURANT_NAME_ENGLISH  \
# 0     35.187                        NaN
# 1     35.186  Haeam Buffet Wedding Hall
# 2     35.186                        NaN
# ...

# %%
bs_re_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   MENU_TYPE                626 non-null    object
#  1   RESTAURANT_NAME_KOREAN   626 non-null    object
#  2   ADDRESS_KOREAN           626 non-null    object
#  3   MENU_NAME                626 non-null    object
#  4   NATIONAL_PHONE_NUMBER    626 non-null    object
#  5   DISTRICT_NAME            626 non-null    object
#  6   LATITUDE                 626 non-null    object
#  7   LONGITUDE                626 non-null    float64
#  8   RESTAURANT_NAME_ENGLISH  201 non-null    object
#  9   ADDRESS_ENGLISH          528 non-null    object
#  10  OPENING_HOURS            404 non-null    object
#  11  RATING                   483 non-null    float64
#  12  RATING_COUNT             483 non-null    float64
#  13  PRICE_LEVEL              193 non-null    object
# ...

# %%
missing_values = bs_re_df.isnull().sum()
missing_values
# Out:
# MENU_TYPE                    0
# RESTAURANT_NAME_KOREAN       0
# ADDRESS_KOREAN               0
# MENU_NAME                    0
# NATIONAL_PHONE_NUMBER        0
# DISTRICT_NAME                0
# LATITUDE                     0
# LONGITUDE                    0
# RESTAURANT_NAME_ENGLISH    425
# ADDRESS_ENGLISH             98
# OPENING_HOURS              222
# RATING                     143
# RATING_COUNT               143
# PRICE_LEVEL                433
# TAKEOUT_YN                 354
# RESERVABLE                 238
# BREAKFAST_YN               460
# LUNCH_YN                   188
# DINNER_YN                  183
# BEER_YN                    197
# OUTDOOR_SEAT_YN            274
# MENU_FOR_CHILDREN_YN       238
# RESTROOM_YN                165
# PARKING_LOT_YN             507
# PAYMENT_OPTIONS            160
# REVIEW                     157
# dtype: int64

# %%
df_rating_missing = bs_re_df[bs_re_df['RATING'].isnull()]

# %%
df_rating_missing
# Out:
#     MENU_TYPE RESTAURANT_NAME_KOREAN            ADDRESS_KOREAN  \
# 2          한식                   할매보쌈                    129.08
# 6          한식                 토곡식육식당                   129.106
# 8          한식           청담동 대구뽈찜 아구찜                   129.083
# 10        뷔페식       주식회사 더파티 더파티 시청점                   129.076
# 14         회집                  원조메기탕                   129.072
# ..        ...                    ...                       ...
# 592        한식        토박이 상황삼계탕.오리불고기                 35.235741
# 593  식육(숯불구이)                 화명참숯갈비                35.2353615
# 594      복어취급                   덕천복집                35.2125481
# 597        한식                  지리산옻닭                35.1959578
# 611  식육(숯불구이)                주식회사세연정  부산광역시 동래구 충렬대로 149 (온천동)
#
#                              MENU_NAME NATIONAL_PHONE_NUMBER DISTRICT_NAME  \
# 2              부산광역시 연제구 연산동 1242번지 6호                    보쌈       00:00.0
# ...

# %%
xls_dir = "/mnt/t7/dnn/llm_practicing/05_RAG_practicing/datas/BUSAN_LOCAL_RESTAURNATS_FILLED.xlsx"
df = pd.read_excel(xls_dir)

# %%
df.head()
# Out:
#   MENU_TYPE RESTAURANT_NAME_KOREAN ADDRESS_KOREAN  \
# 0        한식              해운대 신 대구탕         129.08
# 1       뷔페식                   해암뷔페        129.081
# 2        한식                   할매보쌈         129.08
# 3       중국식                    팔선각        129.075
# 4        일식                   팔미초밥        129.082
#
#                      MENU_NAME NATIONAL_PHONE_NUMBER DISTRICT_NAME LATITUDE  \
# 0   부산광역시 연제구 연산동 1127번지 5호 1층                   대구탕       00:00.0  00:00.0
# 1  부산광역시 연제구 연산동 1242번지 8호 ,13                    뷔페       00:00.0  00:00.0
# 2      부산광역시 연제구 연산동 1242번지 6호                    보쌈       00:00.0  00:00.0
# 3      부산광역시 연제구 거제동 1490번지 2호                    중식       00:00.0  00:00.0
# 4  부산광역시 연제구 연산동 701번지 8호 팔미빌딩                   회초밥       00:00.0  00:00.0
#
#    LONGITUDE    RESTAURANT_NAME_ENGLISH  \
# 0     35.187                        NaN
# 1     35.186  Haeam Buffet Wedding Hall
# 2     35.186                        NaN
# ...
